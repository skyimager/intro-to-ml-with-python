# %% [markdown]
# ### using urllib to read html data from webpages

# %%
from urllib.request import urlopen
x = urlopen('https://www.bbc.co.uk/')
k=x.read()

# %%
k
# Out:
# b'<!DOCTYPE html>\n<!--[if lte IE 9]>\n  <html lang="en-GB" class="no-js no-flexbox no-flexboxlegacy b-reith-sans-font">\n<![endif]-->\n<!--[if gt IE 9]><!-->\n  <html lang="en-GB" class="no-js b-reith-sans-font b-reith-serif-font">\n<!--<![endif]-->\n<head>\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/><script type="text/javascript">\n      var _sf_startpt = (new Date()).getTime();\n    </script><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="The best of the BBC, with the latest news and sport headlines, weather, TV &amp; radio highlights and much more from across the whole of BBC Online" name="description"><meta content="BBC, British Broadcasting Corporation, BBCi, News, Sport, iPlayer, TV, Radio, Food, Music, Business, Arts, Bitesize, Lifestyle, Entertainment, Headlines" name="keywords"><meta property="og:title" content="BBC - Home"><meta property="og:type" content="website"><meta property="og:description" content="The best of the BBC, with the latest news and sport headlines, weather, TV &amp; radio highlights and much more from across the whole of BBC Online"><meta property="og:site_name" content="BBC Homepage"><meta property="og:locale" content="en_GB"><meta property="article:author" content="https://www.facebook.com/bbc"><meta property="og:article:section" content="Home"><meta property="og:url" content="http://www.bbc.co.uk"><meta property="og:image" content="//homepage.files.bbci.co.uk/s/homepage-v5/5.2.1-131.5a88f1535/images/bbc_homepage.png"><meta name="twitter:card" content="summary_large_image"><meta name="twitter:site" content="@bbccouk"><meta name="twitter:title" content="BBC - Home"><meta name="twitter:description" content="The best of the BBC, with the latest news and sport headlines, weather, TV &amp; radio highlights and much more from across the whole of BBC Online"><meta name="twitter:creator" content="@bbccouk"><meta name="twitter:image:src" content="//homepage.files.bbci.co.uk/s/homepage-v5/5.2.1-131.5a88f1535/images/bbc_homepage.png"><meta name="twitter:image:alt" content="BBC Homepage"><meta name="twitter:domain" content="www.bbc.co.uk"><link rel="canonical" href="https://www.bbc.co.uk" /><script type="text/javascript">(function () {if (window.location.pathname === \'/\') { window.bbcredirection = { geo: true }; }})();</script>\n<!-- Environment: live -->\n<!-- Orbit: 3.0.0-780.5d50e4a1 -->\n<!-- Analytics Web Module: 0.0.2-407.0fb42af -->\n<!-- NavID Web Module: 0.2.0-92.e536e2f -->\n<!-- Detectview Web Module: 0.0.2-407.0fb42af -->\n<!-- Searchbox Web Module: 3.0.0-52.e652a74 -->\n<!-- Promo Web Module: 3.0.0-73.cc3da46 -->\n<meta name="viewport" content="width=device-width, initial-scale=1.0"><meta property="fb:admins" content="100004154058350"><link rel="stylesheet" href="https://nav.files.bbci.co.uk/orbit/a07e26191aed6a8725358c88df999791/css/orb-ltr.min.css"><!--[if (lt IE 9) & (!IEMobile)]>\n    <link rel="stylesheet" href="https://nav.files.bbci.co.uk/orbit/a07e26191aed6a8725358c88df999791/css/orb-ie-ltr.min.css">\n    <![endif]--><script type="text/javascript">/*<![CDATA[*/\n        window.orb = {\n            lang: \'en\',\n            bbcBaseUrl: \'https://www.bbc.co.uk\',\n            bbcUrlPrefix: \'https://www.\',\n            staticHost: \'https://nav.files.bbci.co.uk/orbit/a07e26191aed6a8725358c88df999791\',\n            figUrl: \'https://fig.bbc.co.uk/frameworks/fig/2/fig.js\',\n            partialCookieOvenUrl: \'https://cookie-oven.api.bbc\'\n        };\n\n        document.documentElement.className += (document.documentElement.className? \' \' : \'\') + \'orb-js\';\n        window.orb.worldwideNavlinks = \'<li class="orb-nav-homedotcom"><a href="https://www.bbc.com/">Home</a></li><li class="orb-nav-newsdotcom"><a href="https://www.bbc.com/news">News</a></li><li class="orb-nav-sport"><a href="https://www.bbc.com/sport">Sport</a></li><li class="orb-nav-reeldotcom"><a href="https://www.bbc.com/reel">Reel</a></li><li class="orb-nav-wo ...

# %%
parts=str(k).split("<a href=")
parts
# Out:
# ['b\'<!DOCTYPE html>\\n<!--[if lte IE 9]>\\n  <html lang="en-GB" class="no-js no-flexbox no-flexboxlegacy b-reith-sans-font">\\n<![endif]-->\\n<!--[if gt IE 9]><!-->\\n  <html lang="en-GB" class="no-js b-reith-sans-font b-reith-serif-font">\\n<!--<![endif]-->\\n<head>\\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/><script type="text/javascript">\\n      var _sf_startpt = (new Date()).getTime();\\n    </script><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="The best of the BBC, with the latest news and sport headlines, weather, TV &amp; radio highlights and much more from across the whole of BBC Online" name="description"><meta content="BBC, British Broadcasting Corporation, BBCi, News, Sport, iPlayer, TV, Radio, Food, Music, Business, Arts, Bitesize, Lifestyle, Entertainment, Headlines" name="keywords"><meta property="og:title" content="BBC - Home"><meta property="og:type" content="website"><meta property="og:description" content="The best of the BBC, with the latest news and sport headlines, weather, TV &amp; radio highlights and much more from across the whole of BBC Online"><meta property="og:site_name" content="BBC Homepage"><meta property="og:locale" content="en_GB"><meta property="article:author" content="https://www.facebook.com/bbc"><meta property="og:article:section" content="Home"><meta property="og:url" content="http://www.bbc.co.uk"><meta property="og:image" content="//homepage.files.bbci.co.uk/s/homepage-v5/5.2.1-131.5a88f1535/images/bbc_homepage.png"><meta name="twitter:card" content="summary_large_image"><meta name="twitter:site" content="@bbccouk"><meta name="twitter:title" content="BBC - Home"><meta name="twitter:description" content="The best of the BBC, with the latest news and sport headlines, weather, TV &amp; radio highlights and much more from across the whole of BBC Online"><meta name="twitter:creator" content="@bbccouk"><meta name="twitter:image:src" content="//homepage.files.bbci.co.uk/s/homepage-v5/5.2.1-131.5a88f1535/images/bbc_homepage.png"><meta name="twitter:image:alt" content="BBC Homepage"><meta name="twitter:domain" content="www.bbc.co.uk"><link rel="canonical" href="https://www.bbc.co.uk" /><script type="text/javascript">(function () {if (window.location.pathname === \\\'/\\\') { window.bbcredirection = { geo: true }; }})();</script>\\n<!-- Environment: live -->\\n<!-- Orbit: 3.0.0-780.5d50e4a1 -->\\n<!-- Analytics Web Module: 0.0.2-407.0fb42af -->\\n<!-- NavID Web Module: 0.2.0-92.e536e2f -->\\n<!-- Detectview Web Module: 0.0.2-407.0fb42af -->\\n<!-- Searchbox Web Module: 3.0.0-52.e652a74 -->\\n<!-- Promo Web Module: 3.0.0-73.cc3da46 -->\\n<meta name="viewport" content="width=device-width, initial-scale=1.0"><meta property="fb:admins" content="100004154058350"><link rel="stylesheet" href="https://nav.files.bbci.co.uk/orbit/a07e26191aed6a8725358c88df999791/css/orb-ltr.min.css"><!--[if (lt IE 9) & (!IEMobile)]>\\n    <link rel="stylesheet" href="https://nav.files.bbci.co.uk/orbit/a07e26191aed6a8725358c88df999791/css/orb-ie-ltr.min.css">\\n    <![endif]--><script type="text/javascript">/*<![CDATA[*/\\n        window.orb = {\\n            lang: \\\'en\\\',\\n            bbcBaseUrl: \\\'https://www.bbc.co.uk\\\',\\n            bbcUrlPrefix: \\\'https://www.\\\',\\n            staticHost: \\\'https://nav.files.bbci.co.uk/orbit/a07e26191aed6a8725358c88df999791\\\',\\n            figUrl: \\\'https://fig.bbc.co.uk/frameworks/fig/2/fig.js\\\',\\n            partialCookieOvenUrl: \\\'https://cookie-oven.api.bbc\\\'\\n        };\\n\\n        document.documentElement.className += (document.documentElement.className? \\\' \\\' : \\\'\\\') + \\\'orb-js\\\';\\n        window.orb.worldwideNavlinks = \\\'<li class="orb-nav-homedotcom">',
#  '"https://www.bbc.com/">Home</a></li><li class="orb-nav-newsdotcom">',
#  '"https://www.bbc.com/news">News</a></li><li class="orb-nav-sport">',
#  '"https://www.bbc.com/sport">Sport</a></li><li class="orb-nav-reeldotcom">',
#  '"https://www.bbc.com/reel">Reel</a></li><li class="orb-nav-worklife">',
#  '"https://www.bbc.com/worklife">Worklife</a></li><li class="orb-nav-traveldotcom">',
#  '"https://www.bbc.com/travel">Travel</a></li><li class="orb-nav-future">',
#  '"https://www.bbc.com/future">Future</a></li><li class="orb-nav-culture">',
#  '"https://www.bbc.com/culture">Culture</a></li><li class="orb-nav-music">',
#  '"https://www.bbc.com/culture/music">Music</a></li><li class="orb-nav-tv">',
#  '"https://www.bbc.co.uk/schedules/p00fzl9m">TV</a></li><li class="orb-nav-weather">',
#  '"https://www.bbc.com/weather">Weather</a></li><li class="orb-nav-sounds">',
#  '"https://www.bbc.co.uk/sounds">Sounds</a></li>\\\';\\n\\n\\n     /*]]>*/</script><script>// Promise polyfill from https://github.com/bramstein/promis\\n        (function(){\\\'use strict\\\';var f,g=[];function l(a){g.push(a);1==g.length&&f()}function m(){for(;g.length;)g[0](),g.shift()}f=function(){setTimeout(m)};function n(a){this.a=p;this.b=void 0;this.f=[];var b=this;try{a(function(a){q(b,a)},function(a){r(b,a)})}catch(c){r(b,c)}}var p=2;function t(a){return new n(function(b,c){c(a)})}function u(a){return new n(function(b){b(a)})}function q(a,b){if(a.a==p){if(b==a)throw new TypeError;var c=!1;try{var d=b&&b.then;if(null!=b&&"object"==typeof b&&"function"==typeof d){d.call(b,function(b){c||q(a,b);c=!0},function(b){c||r(a,b);c=!0});return}}catch(e){c||r(a,e);return}a.a=0;a.b=b;v(a)}} function r(a,b){if(a.a==p){if(b==a)throw new TypeError;a.a=1;a.b=b;v(a)}}function v(a){l(function(){if(a.a!=p)for(;a.f.length;){var b=a.f.shift(),c=b[0],d=b[1],e=b[2],b=b[3];try{0==a.a?"function"==typeof c?e(c.call(void 0,a.b)):e(a.b):1==a.a&&("function"==typeof d?e(d.call(void 0,a.b)):b(a.b))}catch(h){b(h)}}})}n.prototype.g=function(a){return this.c(void 0,a)};n.prototype.c=function(a,b){var c=this;return new n(function(d,e){c.f.push([a,b,d,e]);v(c)})}; function w(a){return new n(function(b,c){function d(c){return function(d){h[c]=d;e+=1;e==a.length&&b(h)}}var e=0,h=[];0==a.length&&b(h);for(var k=0;k<a.length;k+=1)u(a[k]).c(d(k),c)})}function x(a){return new n(function(b,c){for(var d=0;d<a.length;d+=1)u(a[d]).c(b,c)})};window.Promise||(window.Promise=n,window.Promise.resolve=u,window.Promise.reject=t,window.Promise.race=x,window.Promise.all=w,window.Promise.prototype.then=n.prototype.c,window.Promise.prototype["catch"]=n.prototype.g);}());\\n    \\n    \\n        // Polyfill Event constructor for IE ref: https://jira.dev.bbc.co.uk/browse/ORBITEN-919\\n        // see: https://stackoverflow.com/questions/26596123\\n        (function () {\\n          if (typeof window.CustomEvent === "function") {\\n            return false;\\n          }\\n          function CustomEvent(event, params) {\\n            params = params || { bubbles: false, cancelable: false, detail: undefined };\\n            var evt = document.createEvent(\\\'CustomEvent\\\');\\n            evt.initCustomEvent(event, params.bubbles, params.cancelable, params.detail);\\n            return evt;\\n          }\\n          CustomEvent.prototype = window.Event.prototype;\\n          window.Event = CustomEvent;\\n        })();\\n    \\n    \\n        //Element.prototype.matches polyfill\\n        //from https://developer.mozilla.org/en-US/docs/Web/API/Element/matches#Polyfill\\n        if (!Element.prototype.matches) {\\n          Element.prototype.matches = Element.prototype.msMatchesSelector ||\\n                                      Element.prototype.webkitMatchesSelector;\\n        }\\n        //NodeList.forEach Polyfill\\n        //from https://developer.mozilla.org/en-US/docs/Web/API/NodeList/forEach#Polyfill\\n        if (window.NodeList && !NodeList.prototype.forEach) {\\n          NodeList.prototype.forEach = Array.prototype.forEach;\\n        }\\n    \\n        // Object.assign polyfill from https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Object/assign#Polyfill\\n        if (typeof Object.assign != \\\'function\\\') {\\n          // Must be writable: true, enumerable: false, configurable: true\\n          Object.defineProperty(Object, "assign", {\\n            value: function assign(target, varArgs) { // .length of function is 2\\n              \\\'use strict\\\';\\n              if (target == null) { // TypeError if undefined or null\\n                throw new TypeError(\\\'Cannot convert undefined or null to object\\\');\\n              }\\n    \\n              var to = Object(target);\\n    \\n              for (var index = 1; index < arguments.length; index++) {\\n                var nextSource = arguments[index];\\n    \\n                 ...
#  '"https://www.bbc.co.uk">Homepage</a></div><section><div class="orb-skip-links"><h2>Accessibility links</h2><ul><li>',
#  '"#hp-bbc-homepage-content">Skip to content</a></li><li><a id="orb-accessibility-help" href="/accessibility/">Accessibility Help</a></li></ul></div></section><div id="mybbc-wrapper" class="orb-nav-section orb-nav-id orb-nav-focus orb-nav-id-default"><div id="idcta-statusbar" class="orb-nav-section orb-nav-focus" data-bbc-container="id-cta" data-bbc-event-type="click" data-bbc-ignore-views="1" data-bbc-metadata="{&quot;id-cta-type&quot;: &quot;statusbar-orb&quot;}" data-bbc-source="responsive_web" data-bbc-title="id-cta-sign-in"><a id="idcta-link" href="https://account.bbc.com/account"><span id="idcta-username">BBC Account</span></a></div><script type="text/javascript">require([\\\'idcta/statusbar\\\'], function (statusbar) {new statusbar.Statusbar({id: \\\'idcta-statusbar\\\', publiclyCacheable: true});});</script><!-- Because we are now loading the notification bell CSS asynchronously, we need this inline style hack to ensure that the notification div \\n\\t\\t is hidden by default, and shown only if and when the bell code is loaded from notification-ui --><a id="notification-link" class="js-notification-link animated three" href="#" style="display: none"><span class="hidden-span">Notifications</span><div class="notification-link--triangle"></div><div class="notification-link--triangle"></div><span id="not-num"></span></a></div><nav role="navigation" aria-label="BBC" class="orb-nav"><div class="orb-nav-section orb-nav-links orb-nav-focus" id="orb-nav-links"><ul><li class="orb-nav-home">',
#  '"https://www.bbc.co.uk">Home</a></li><li class="orb-nav-news">',
#  '"https://www.bbc.co.uk/news">News</a></li><li class="orb-nav-sport">',
#  '"https://www.bbc.co.uk/sport">Sport</a></li><li class="orb-nav-weather">',
#  '"https://www.bbc.co.uk/weather">Weather</a></li><li class="orb-nav-iplayer">',
#  '"https://www.bbc.co.uk/iplayer">iPlayer</a></li><li class="orb-nav-sounds">',
#  '"https://www.bbc.co.uk/sounds">Sounds</a></li><li class="orb-nav-cbbc">',
#  '"https://www.bbc.co.uk/cbbc">CBBC</a></li><li class="orb-nav-cbeebies">',
#  '"https://www.bbc.co.uk/cbeebies">CBeebies</a></li><li class="orb-nav-food">',
#  '"https://www.bbc.co.uk/food">Food</a></li><li class="orb-nav-bitesize">',
#  '"https://www.bbc.co.uk/bitesize">Bitesize</a></li><li class="orb-nav-arts">',
#  '"https://www.bbc.co.uk/arts">Arts</a></li><li class="orb-nav-taster">',
#  '"https://www.bbc.co.uk/taster">Taster</a></li><li class="orb-nav-local">',
#  '"https://www.bbc.co.uk/news/localnews">Local</a></li><li class="orb-nav-tv">',
#  '"https://www.bbc.co.uk/tv">TV</a></li><li class="orb-nav-radio">',
#  '"https://www.bbc.co.uk/radio">Radio</a></li><li class="orb-nav-three">',
#  '"https://www.bbc.co.uk/bbcthree">Three</a></li><li id="orb-nav-more" style="width: 88px" aria-controls="orb-panel-more">',
#  '"#orb-footer" data-alt="More" class="istats-notrack">Menu<span class="orb-icon orb-icon-arrow"></span></a></li></ul></div></nav><div class="orb-nav-section orb-nav-search"><a class="orb-search__button" href="https://search.bbc.co.uk/search" title="Search the BBC">Search</a><form class="b-f" id="orb-search-form" role="search" method="get" action="https://search.bbc.co.uk/search" accept-charset="utf-8"><div><label for="orb-search-q">Search the BBC</label><input id="orb-search-q" type="text" autocomplete="off" autocorrect="off" autocapitalize="off" spellcheck="false" name="q" placeholder="Search"><button id="orb-search-button" class="orb-search__button">Search the BBC</button><input type="hidden" name="suggid" id="orb-search-suggid"></div></form></div></div><div id="orb-panels"></div></div></header>  <!-- Styling hook for shared modules only -->\\n<div id="orb-modules">\\n<!--[if lt IE 9]><div class="hp-browser-notify"><div class="hp-browser-notify__banner"><div class="hp-browser-notify__icon"></div><span class="hp-browser-notify__text gel-brevier">This site is optimised for modern web browsers, and does not fully support your version of Internet Explorer</span></div></div><![endif]--><h1 id="hp-bbc-homepage-content" class="hp-main-heading">BBC Homepage</h1><div class="hp-top-modules" data-bbc-track-position=1></div><div class="hp-modules" role="main" data-bbc-track-position=1><section class="hp-module hp-banner-container">\\n  <div class="hp-banner hp-banner--locked">\\n    <h2 class="hp-banner__text">Welcome to the BBC</h2>\\n    <time class="hp-banner__date gel-pica" datetime="2019-12-15T11:11:38.360Z">\\n      Sunday, 15 December\\n    </time>\\n    \\n  </div>\\n</section>\\n<section class="hp-module uk-hero-promos-container" ><div class="hp-module__container hp-module--light-theme" data-reference-key="uk_hero_promos_1576408295113_it25swj5sj5poplvkc07ldi" data-template="HeroPromos" data-stats="{&quot;hp_module_name&quot;:&quot;gb hero&quot;,&quot;link_location&quot;:&quot;hero-module&quot;,&quot;hp_module_template&quot;:1,&quot;hp_sgm_variant&quot;:&quot;0&quot;,&quot;hp_sgm_id&quot;:&quot;&quot;,&quot;hp_sgm_user_score&quot;:&quot;&quot;,&quot;hp_sgm_user_met_criteria&quot;:&quot;0&quot;}" data-file-id="collection-uk-hero-promos-with-ck-and-nations-overrides" data-namespace="gb hero" data-hp-interest="{&quot;id&quot;:&quot;ukheroes&quot;,&quot;title&quot;:&quot;UK heroes&quot;}" data-reactid=".1gr44x3x9xc" data-react-checksum="1294502887"><div class="top-stories hp-module__content" data-reactid=".1gr44x3x9xc.0"><div class="top-stories__stories gel-layout top-stories__stories--with-images top-stories__stories--all-images" data-reactid=".1gr44x3x9xc.0.1"><div class="top-story__wrapper gel-layout__item hp-bp-m-one-half hp-ts--news" data-bbc-container="gb hero" data-bbc-content-id="https://www.bbc.co.uk/news/election-2019-50799792" data-bbc-content-label="Labour leadership takes blame over result" data-bbc-source="Election 2019" data-bbc-asset-type="article" data-bbc-personalisation="{&quot;EDN&quot;:&quot;uk&quot;}" data-bbc-metadata="{&quot;IMG&quot;:&quot;urn:bbc:imagepid:p07xz6d3&quot;}" data-reactid=".1gr44x3x9xc.0.1.0">',
#  '"https://www.bbc.co.uk/news/election-2019-50799792" class="top-story" data-reactid=".1gr44x3x9xc.0.1.0.$hp-ts-0"><div class="top-story__image-wrapper" data-reactid=".1gr44x3x9xc.0.1.0.$hp-ts-0.0"><div class="top-story__image" data-image-recipe="//ichef.bbci.co.uk/images/ic/$recipe/p07xz6d3.jpg" style="background-image:url(//ichef.bbci.co.uk/images/ic/384x216/p07xz6d3.jpg);" data-reactid=".1gr44x3x9xc.0.1.0.$hp-ts-0.0.0"></div><noscript data-reactid=".1gr44x3x9xc.0.1.0.$hp-ts-0.0.$no-js"><div class="top-story__image top-story__image--fallback top-story__image--visible" style="background-image:url(//ichef.bbci.co.uk/images/ic/384x216/p07xz6d3.jpg);"></div></noscript></div><div class="top-story__content" data-reactid=".1gr44x3x9xc.0.1.0.$hp-ts-0.1"><h3 class="gel-double-pica-bold top-story__title-container" data-reactid=".1gr44x3x9xc.0.1.0.$hp-ts-0.1.0"><span class="top-story__title" data-reactid=".1gr44x3x9xc.0.1.0.$hp-ts-0.1.0.1">Labour leadership takes blame over result</span></h3></div><span class="gel-minion top-story__attr-container" aria-labelledby="hp-ts-0-collection-uk-hero-promos-with-ck-and-nations-overrides" data-reactid=".1gr44x3x9xc.0.1.0.$hp-ts-0.2"><span id="hp-ts-0-collection-uk-hero-promos-with-ck-and-nations-overrides" data-reactid=".1gr44x3x9xc.0.1.0.$hp-ts-0.2.0"><span class="hp-accessibility-label" data-reactid=".1gr44x3x9xc.0.1.0.$hp-ts-0.2.0.0">From </span><span class="top-story__attr" data-reactid=".1gr44x3x9xc.0.1.0.$hp-ts-0.2.0.1">Election 2019</span></span></span></a></div><div class="top-story__wrapper top-story--small-image gel-layout__item gel-one-half hp-bp-m-one-quarter hp-ts--news" data-bbc-container="gb hero" data-bbc-content-id="https://www.bbc.co.uk/news/world-asia-50798205" data-bbc-content-label="NZ volcano: Death toll rises with two still missing" data-bbc-source="Asia" data-bbc-asset-type="article" data-bbc-personalisation="{&quot;EDN&quot;:&quot;uk&quot;}" data-bbc-metadata="{&quot;IMG&quot;:&quot;urn:bbc:imagepid:p07xyyn1&quot;}" data-reactid=".1gr44x3x9xc.0.1.1">',
#  '"https://www.bbc.co.uk/news/world-asia-50798205" class="top-story" data-reactid=".1gr44x3x9xc.0.1.1.$hp-ts-1"><div class="top-story__image-wrapper" data-reactid=".1gr44x3x9xc.0.1.1.$hp-ts-1.0"><div class="top-story__image" data-image-recipe="//ichef.bbci.co.uk/images/ic/$recipe/p07xyyn1.jpg" style="background-image:url(//ichef.bbci.co.uk/images/ic/384x216/p07xyyn1.jpg);" data-reactid=".1gr44x3x9xc.0.1.1.$hp-ts-1.0.0"></div><noscript data-reactid=".1gr44x3x9xc.0.1.1.$hp-ts-1.0.$no-js"><div class="top-story__image top-story__image--fallback top-story__image--visible" style="background-image:url(//ichef.bbci.co.uk/images/ic/384x216/p07xyyn1.jpg);"></div></noscript></div><div class="top-story__content" data-reactid=".1gr44x3x9xc.0.1.1.$hp-ts-1.1"><h3 class="gel-pica-bold top-story__title-container" data-reactid=".1gr44x3x9xc.0.1.1.$hp-ts-1.1.0"><span class="top-story__title" data-reactid=".1gr44x3x9xc.0.1.1.$hp-ts-1.1.0.1">NZ volcano: Death toll rises with two still missing</span></h3></div><span class="gel-minion top-story__attr-container" aria-labelledby="hp-ts-1-collection-uk-hero-promos-with-ck-and-nations-overrides" data-reactid=".1gr44x3x9xc.0.1.1.$hp-ts-1.2"><span id="hp-ts-1-collection-uk-hero-promos-with-ck-and-nations-overrides" data-reactid=".1gr44x3x9xc.0.1.1.$hp-ts-1.2.0"><span class="hp-accessibility-label" data-reactid=".1gr44x3x9xc.0.1.1.$hp-ts-1.2.0.0">From </span><span class="top-story__attr" data-reactid=".1gr44x3x9xc.0.1.1.$hp-ts-1.2.0.1">Asia</span></span></span></a></div><div class="top-story__wrapper top-story--small-image gel-layout__item gel-one-half hp-bp-m-one-quarter hp-ts--news" data-bbc-container="gb hero" data-bbc-content-id="https://www.bbc.co.uk/news/entertainment-arts-50763782" data-bbc-content-label="&#x27;I&#x27;m not stuck on the conveyor belt anymore&#x27;" data-bbc-source="Entertainment &amp; Arts" data-bbc-asset-type="article" data-bbc-personalisation="{&quot;EDN&quot;:&quot;uk&quot;}" data-bbc-metadata="{&quot;IMG&quot;:&quot;urn:bbc:imagepid:p07xz3r1&quot;}" data-reactid=".1gr44x3x9xc.0.1.2">',
#  '"https://www.bbc.co.uk/news/entertainment-arts-50763782" class="top-story" data-reactid=".1gr44x3x9xc.0.1.2.$hp-ts-2"><div class="top-story__image-wrapper" data-reactid=".1gr44x3x9xc.0.1.2.$hp-ts-2.0"><div class="top-story__image" data-image-recipe="//ichef.bbci.co.uk/images/ic/$recipe/p07xz3r1.jpg" style="background-image:url(//ichef.bbci.co.uk/images/ic/384x216/p07xz3r1.jpg);" data-reactid=".1gr44x3x9xc.0.1.2.$hp-ts-2.0.0"></div><noscript data-reactid=".1gr44x3x9xc.0.1.2.$hp-ts-2.0.$no-js"><div class="top-story__image top-story__image--fallback top-story__image--visible" style="background-image:url(//ichef.bbci.co.uk/images/ic/384x216/p07xz3r1.jpg);"></div></noscript></div><div class="top-story__content" data-reactid=".1gr44x3x9xc.0.1.2.$hp-ts-2.1"><h3 class="gel-pica-bold top-story__title-container" data-reactid=".1gr44x3x9xc.0.1.2.$hp-ts-2.1.0"><span class="top-story__title" data-reactid=".1gr44x3x9xc.0.1.2.$hp-ts-2.1.0.1">&#x27;I&#x27;m not stuck on the conveyor belt anymore&#x27;</span></h3></div><span class="gel-minion top-story__attr-container" aria-labelledby="hp-ts-2-collection-uk-hero-promos-with-ck-and-nations-overrides" data-reactid=".1gr44x3x9xc.0.1.2.$hp-ts-2.2"><span id="hp-ts-2-collection-uk-hero-promos-with-ck-and-nations-overrides" data-reactid=".1gr44x3x9xc.0.1.2.$hp-ts-2.2.0"><span class="hp-accessibility-label" data-reactid=".1gr44x3x9xc.0.1.2.$hp-ts-2.2.0.0">From </span><span class="top-story__attr" data-reactid=".1gr44x3x9xc.0.1.2.$hp-ts-2.2.0.1">Entertainment &amp; Arts</span></span></span></a></div></div><script data-reactid=".1gr44x3x9xc.0.2">window.bbcIso = window.bbcIso || {}; window.bbcIso[\\\'uk_hero_promos_1576408295113_it25swj5sj5poplvkc07ldi\\\'] = {"title":"","newTag":false,"contentModel":{"topStories":[{"urn":"urn:bbc:homepagepromo:9d00fc91bfd2e59cf7bf016591ad435f","title":"Labour leadership takes blame over result","url":"https://www.bbc.co.uk/news/election-2019-50799792","image":{"templateUrl":"ichef.bbci.co.uk/images/ic/$recipe/p07xz6d3.jpg","altText":null,"copyright":null},"attribution":"Election 2019","assetType":"article","liveBadge":false,"promoTopic":"news","description":null,"cta":{},"altFont":true},{"urn":"urn:bbc:homepagepromo:d6b21530338a4abab779dc9d549f26b6","title":"NZ volcano: Death toll rises with two still missing","url":"https://www.bbc.co.uk/news/world-asia-50798205","image":{"templateUrl":"ichef.bbci.co.uk/images/ic/$recipe/p07xyyn1.jpg","altText":null,"copyright":null},"attribution":"Asia","assetType":"article","liveBadge":false,"promoTopic":"news","description":null,"cta":{}},{"urn":"urn:bbc:homepagepromo:cbb76c94ebd2ae0ea4ca5359fb6cbf23","title":"\\\'I\\\'m not stuck on the conveyor belt anymore\\\'","url":"https://www.bbc.co.uk/news/entertainment-arts-50763782","image":{"templateUrl":"ichef.bbci.co.uk/images/ic/$recipe/p07xz3r1.jpg","altText":null,"copyright":null},"attribution":"Entertainment & Arts","assetType":"article","liveBadge":false,"promoTopic":"news","description":null,"cta":{}}]},"maxStoriesToDisplay":3,"footer":{"url":""},"url":"","colorPalette":"","template":"HeroPromos","moduleTheme":"lightTheme","imageTemplateUrl":"ichef.bbci.co.uk/images/ic/$recipe/$pid.jpg","isPaired":false,"backgroundImage":"","talentBackgroundColour":"","refKey":"uk_hero_promos_1576408295113_it25swj5sj5poplvkc07ldi","fileId":"collection-uk-hero-promos-with-ck-and-nations-overrides","initialRenderHidden":false,"containerElementAttributes":{"data-namespace":"gb hero","data-stats":"{\\\\"hp_module_name\\\\":\\\\"gb hero\\\\",\\\\"link_location\\\\":\\\\"hero-module\\\\",\\\\"hp_module_template\\\\":1,\\\\"hp_sgm_variant\\\\":\\\\"0\\\\",\\\\"hp_sgm_id\\\\":\\\\"\\\\",\\\\"hp_sgm_user_score\\\\":\\\\"\\\\",\\\\"hp_sgm_user_met_criteria\\\\":\\\\"0\\\\"}","data-hp-interest":"{\\\\"id\\\\":\\\\"ukheroes\\\\",\\\\"title\\\\":\\\\"UK heroes\\\\"}"},"showVariant":false,"segmentationId":"","metVariantCriteria":false,"renderInitialImages":true,"talentSubtitle":"","talentImage":""};</script>< ...
#  '"https://www.bbc.co.uk/news/live/election-2019-50798916" class="top-story" data-reactid=".1m67c2xobq.0.1.0.$hp-ts-0"><div class="top-story__image-wrapper" data-reactid=".1m67c2xobq.0.1.0.$hp-ts-0.0"><div class="top-story__image" data-image-recipe="//ichef.bbci.co.uk/images/ic/$recipe/p07xz3s3.jpg" data-lazy="//ichef.bbci.co.uk/images/ic/384x216/p07xz3s3.jpg" data-reactid=".1m67c2xobq.0.1.0.$hp-ts-0.0.0"></div><noscript data-reactid=".1m67c2xobq.0.1.0.$hp-ts-0.0.$no-js"><div class="top-story__image top-story__image--fallback top-story__image--visible" style="background-image:url(//ichef.bbci.co.uk/images/ic/384x216/p07xz3s3.jpg);"></div></noscript></div><div class="top-story__content" data-reactid=".1m67c2xobq.0.1.0.$hp-ts-0.1"><h3 class="gel-pica-bold top-story__title-container" data-reactid=".1m67c2xobq.0.1.0.$hp-ts-0.1.0"><span class="hp-live-badge top-story__live-badge hp-badge--red" data-reactid=".1m67c2xobq.0.1.0.$hp-ts-0.1.0.0"></span><span class="top-story__title" data-reactid=".1m67c2xobq.0.1.0.$hp-ts-0.1.0.1">Sunday TV shows react to Tory election win</span><span class="hp-accessibility-label" data-reactid=".1m67c2xobq.0.1.0.$hp-ts-0.1.0.2">. Live now.</span></h3></div><span class="gel-minion top-story__attr-container" aria-labelledby="hp-ts-0-collection-election-extra" data-reactid=".1m67c2xobq.0.1.0.$hp-ts-0.2"><span id="hp-ts-0-collection-election-extra" data-reactid=".1m67c2xobq.0.1.0.$hp-ts-0.2.0"><span class="hp-accessibility-label" data-reactid=".1m67c2xobq.0.1.0.$hp-ts-0.2.0.0">From </span><span class="top-story__attr" data-reactid=".1m67c2xobq.0.1.0.$hp-ts-0.2.0.1">Election 2019</span></span></span></a></div><div class="top-story__wrapper gel-layout__item hp-bp-m-one-third top-story--small-image hp-ts--news" data-bbc-container="election extra" data-bbc-content-id="https://www.bbc.co.uk/news/newsbeat-50779961" data-bbc-content-label="What happens when you lose your job as an MP?" data-bbc-source="Newsbeat" data-bbc-asset-type="article" data-bbc-personalisation="{&quot;EDN&quot;:&quot;uk&quot;}" data-bbc-metadata="{&quot;IMG&quot;:&quot;urn:bbc:imagepid:p07xy3p1&quot;}" data-reactid=".1m67c2xobq.0.1.1">',
#  '"https://www.bbc.co.uk/news/newsbeat-50779961" class="top-story" data-reactid=".1m67c2xobq.0.1.1.$hp-ts-1"><div class="top-story__image-wrapper" data-reactid=".1m67c2xobq.0.1.1.$hp-ts-1.0"><div class="top-story__image" data-image-recipe="//ichef.bbci.co.uk/images/ic/$recipe/p07xy3p1.jpg" data-lazy="//ichef.bbci.co.uk/images/ic/384x216/p07xy3p1.jpg" data-reactid=".1m67c2xobq.0.1.1.$hp-ts-1.0.0"></div><noscript data-reactid=".1m67c2xobq.0.1.1.$hp-ts-1.0.$no-js"><div class="top-story__image top-story__image--fallback top-story__image--visible" style="background-image:url(//ichef.bbci.co.uk/images/ic/384x216/p07xy3p1.jpg);"></div></noscript></div><div class="top-story__content" data-reactid=".1m67c2xobq.0.1.1.$hp-ts-1.1"><h3 class="gel-pica-bold top-story__title-container" data-reactid=".1m67c2xobq.0.1.1.$hp-ts-1.1.0"><span class="top-story__title" data-reactid=".1m67c2xobq.0.1.1.$hp-ts-1.1.0.1">What happens when you lose your job as an MP?</span></h3></div><span class="gel-minion top-story__attr-container" aria-labelledby="hp-ts-1-collection-election-extra" data-reactid=".1m67c2xobq.0.1.1.$hp-ts-1.2"><span id="hp-ts-1-collection-election-extra" data-reactid=".1m67c2xobq.0.1.1.$hp-ts-1.2.0"><span class="hp-accessibility-label" data-reactid=".1m67c2xobq.0.1.1.$hp-ts-1.2.0.0">From </span><span class="top-story__attr" data-reactid=".1m67c2xobq.0.1.1.$hp-ts-1.2.0.1">Newsbeat</span></span></span></a></div><div class="top-story__wrapper gel-layout__item hp-bp-m-one-third top-story--small-image hp-ts--other" data-bbc-container="election extra" data-bbc-content-id="https://www.bbc.co.uk/news/election-2019-50786212" data-bbc-content-label="10 names to keep an eye on in Parliament" data-bbc-source="Election 2019" data-bbc-asset-type="article" data-bbc-personalisation="{&quot;EDN&quot;:&quot;uk&quot;}" data-bbc-metadata="{&quot;IMG&quot;:&quot;urn:bbc:imagepid:_110139256_c4256a26-fbc8-420d-aeb1-c862d5e87b89&quot;}" data-reactid=".1m67c2xobq.0.1.2">',
#  '"https://www.bbc.co.uk/news/election-2019-50786212" class="top-story" data-reactid=".1m67c2xobq.0.1.2.$hp-ts-2"><div class="top-story__image-wrapper" data-reactid=".1m67c2xobq.0.1.2.$hp-ts-2.0"><div class="top-story__image" data-image-recipe="//ichef.bbci.co.uk/curationkit-ichef/$recipe/cpsprodpb/FF0D/production/_110139256_c4256a26-fbc8-420d-aeb1-c862d5e87b89.jpg" data-lazy="//ichef.bbci.co.uk/curationkit-ichef/384x216/cpsprodpb/FF0D/production/_110139256_c4256a26-fbc8-420d-aeb1-c862d5e87b89.jpg" data-reactid=".1m67c2xobq.0.1.2.$hp-ts-2.0.0"></div><noscript data-reactid=".1m67c2xobq.0.1.2.$hp-ts-2.0.$no-js"><div class="top-story__image top-story__image--fallback top-story__image--visible" style="background-image:url(//ichef.bbci.co.uk/curationkit-ichef/384x216/cpsprodpb/FF0D/production/_110139256_c4256a26-fbc8-420d-aeb1-c862d5e87b89.jpg);"></div></noscript></div><div class="top-story__content" data-reactid=".1m67c2xobq.0.1.2.$hp-ts-2.1"><h3 class="gel-pica-bold top-story__title-container" data-reactid=".1m67c2xobq.0.1.2.$hp-ts-2.1.0"><span class="top-story__title" data-reactid=".1m67c2xobq.0.1.2.$hp-ts-2.1.0.1">10 names to keep an eye on in Parliament</span></h3></div><span class="gel-minion top-story__attr-container" aria-labelledby="hp-ts-2-collection-election-extra" data-reactid=".1m67c2xobq.0.1.2.$hp-ts-2.2"><span id="hp-ts-2-collection-election-extra" data-reactid=".1m67c2xobq.0.1.2.$hp-ts-2.2.0"><span class="hp-accessibility-label" data-reactid=".1m67c2xobq.0.1.2.$hp-ts-2.2.0.0">From </span><span class="top-story__attr" data-reactid=".1m67c2xobq.0.1.2.$hp-ts-2.2.0.1">Election 2019</span></span></span></a></div></div><script data-reactid=".1m67c2xobq.0.2">window.bbcIso = window.bbcIso || {}; window.bbcIso[\\\'top_stories_1576408267592_11hewiksmqykoyianed841jor\\\'] = {"title":"Election extra","newTag":false,"contentModel":{"topStories":[{"urn":"urn:bbc:homepagepromo:e25f9df66dca1e8df6d7dde44130db68","title":"Sunday TV shows react to Tory election win","url":"https://www.bbc.co.uk/news/live/election-2019-50798916","image":{"templateUrl":"ichef.bbci.co.uk/images/ic/$recipe/p07xz3s3.jpg","altText":null,"copyright":null},"attribution":"Election 2019","assetType":"article","liveBadge":true,"promoTopic":"news","description":null,"cta":{}},{"urn":"urn:bbc:homepagepromo:2f08942c7bbfd24eaf25c7f8652dca48","title":"What happens when you lose your job as an MP?","url":"https://www.bbc.co.uk/news/newsbeat-50779961","image":{"templateUrl":"ichef.bbci.co.uk/images/ic/$recipe/p07xy3p1.jpg","altText":null,"copyright":null},"attribution":"Newsbeat","assetType":"article","liveBadge":false,"promoTopic":"news","description":null,"cta":{}},{"urn":"urn:bbc:cps:news:election-2019-50786212","title":"10 names to keep an eye on in Parliament","url":"https://www.bbc.co.uk/news/election-2019-50786212","image":{"templateUrl":"ichef.bbci.co.uk/curationkit-ichef/$recipe/cpsprodpb/FF0D/production/_110139256_c4256a26-fbc8-420d-aeb1-c862d5e87b89.jpg","altText":"Eleanor Laing","copyright":"Getty Images"},"attribution":"Election 2019","assetType":"article","liveBadge":false,"promoTopic":"other","description":"Here are some of the MPs who could exert influence in the newly elected House of Commons.","cta":{}},{"urn":"urn:bbc:homepagepromo:a67374dc662234aa71df53f5160bd6d2","title":"How \\\'Beast of Bolsover\\\' lost his seat after 49 years","url":"https://www.bbc.co.uk/news/election-2019-50777371","image":{"templateUrl":"ichef.bbci.co.uk/images/ic/$recipe/p07xxnxd.jpg","altText":null,"copyright":null},"attribution":"Election 2019","assetType":"article","liveBadge":false,"promoTopic":"news","description":null,"cta":{}},{"urn":"urn:bbc:homepagepromo:97551c859ba2f570b0eb1e5491762fb7","title":"\\\'We are not the masters but the servants now\\\'","url":"https://www.bbc.co.uk/news/av/election-2019-50794643/boris-johnson-visits-north-east-england-after-conservative-gains","image":{"templateUrl":"ichef.bbci.co.uk/images/ic/$recipe/p07xy4hn.jpg","altText":null,"copyr ...
#  '"https://www.bbc.co.uk/blogs/strictlycomedancing/entries/d34246b9-0ea4-49c0-9435-6a4c4910f708" class="top-story" data-reactid=".gvhr1sa3fw.0.1.0.$hp-ts-0"><div class="top-story__image-wrapper" data-reactid=".gvhr1sa3fw.0.1.0.$hp-ts-0.0"><div class="top-story__image" data-image-recipe="//ichef.bbci.co.uk/images/ic/$recipe/p07xz79c.jpg" data-lazy="//ichef.bbci.co.uk/images/ic/384x216/p07xz79c.jpg" data-reactid=".gvhr1sa3fw.0.1.0.$hp-ts-0.0.0"></div><noscript data-reactid=".gvhr1sa3fw.0.1.0.$hp-ts-0.0.$no-js"><div class="top-story__image top-story__image--fallback top-story__image--visible" style="background-image:url(//ichef.bbci.co.uk/images/ic/384x216/p07xz79c.jpg);"></div></noscript></div><div class="top-story__content" data-reactid=".gvhr1sa3fw.0.1.0.$hp-ts-0.1"><h3 class="gel-pica-bold top-story__title-container" data-reactid=".gvhr1sa3fw.0.1.0.$hp-ts-0.1.0"><span class="top-story__title" data-reactid=".gvhr1sa3fw.0.1.0.$hp-ts-0.1.0.1">Kelvin and Oti crowned Strictly winners</span></h3></div><span class="gel-minion top-story__attr-container" aria-labelledby="hp-ts-0-collection-more-top-stories" data-reactid=".gvhr1sa3fw.0.1.0.$hp-ts-0.2"><span id="hp-ts-0-collection-more-top-stories" data-reactid=".gvhr1sa3fw.0.1.0.$hp-ts-0.2.0"><span class="hp-accessibility-label" data-reactid=".gvhr1sa3fw.0.1.0.$hp-ts-0.2.0.0">From </span><span class="top-story__attr" data-reactid=".gvhr1sa3fw.0.1.0.$hp-ts-0.2.0.1">BBC One</span></span></span></a></div><div class="top-story__wrapper gel-layout__item hp-bp-m-one-third top-story--small-image hp-ts--other" data-bbc-container="more top stories" data-bbc-content-id="https://www.bbc.co.uk/bitesize/articles/zjtkbdm" data-bbc-content-label="&#x27;I was made to feel on the bottom of the food chain&#x27;" data-bbc-source="BBC Bitesize" data-bbc-asset-type="article" data-bbc-personalisation="{&quot;EDN&quot;:&quot;uk&quot;}" data-bbc-metadata="{&quot;IMG&quot;:&quot;urn:bbc:imagepid:p07kdqds&quot;}" data-reactid=".gvhr1sa3fw.0.1.1">',
#  '"https://www.bbc.co.uk/bitesize/articles/zjtkbdm" class="top-story" data-reactid=".gvhr1sa3fw.0.1.1.$hp-ts-1"><div class="top-story__image-wrapper" data-reactid=".gvhr1sa3fw.0.1.1.$hp-ts-1.0"><div class="top-story__image" data-image-recipe="//ichef.bbci.co.uk/images/ic/$recipe/p07kdqds.jpg" data-lazy="//ichef.bbci.co.uk/images/ic/384x216/p07kdqds.jpg" data-reactid=".gvhr1sa3fw.0.1.1.$hp-ts-1.0.0"></div><noscript data-reactid=".gvhr1sa3fw.0.1.1.$hp-ts-1.0.$no-js"><div class="top-story__image top-story__image--fallback top-story__image--visible" style="background-image:url(//ichef.bbci.co.uk/images/ic/384x216/p07kdqds.jpg);"></div></noscript></div><div class="top-story__content" data-reactid=".gvhr1sa3fw.0.1.1.$hp-ts-1.1"><h3 class="gel-pica-bold top-story__title-container" data-reactid=".gvhr1sa3fw.0.1.1.$hp-ts-1.1.0"><span class="top-story__title" data-reactid=".gvhr1sa3fw.0.1.1.$hp-ts-1.1.0.1">&#x27;I was made to feel on the bottom of the food chain&#x27;</span></h3></div><span class="gel-minion top-story__attr-container" aria-labelledby="hp-ts-1-collection-more-top-stories" data-reactid=".gvhr1sa3fw.0.1.1.$hp-ts-1.2"><span id="hp-ts-1-collection-more-top-stories" data-reactid=".gvhr1sa3fw.0.1.1.$hp-ts-1.2.0"><span class="hp-accessibility-label" data-reactid=".gvhr1sa3fw.0.1.1.$hp-ts-1.2.0.0">From </span><span class="top-story__attr" data-reactid=".gvhr1sa3fw.0.1.1.$hp-ts-1.2.0.1">BBC Bitesize</span></span></span></a></div><div class="top-story__wrapper gel-layout__item hp-bp-m-one-third top-story--small-image hp-ts--sport" data-bbc-container="more top stories" data-bbc-content-id="https://www.bbc.co.uk/sport/sports-personality/50729382" data-bbc-content-label="How well do you know your Sports Personality winners?" data-bbc-source="Sports Personality" data-bbc-asset-type="article" data-bbc-personalisation="{&quot;EDN&quot;:&quot;uk&quot;}" data-bbc-metadata="{&quot;IMG&quot;:&quot;urn:bbc:imagepid:p07xs0vp&quot;}" data-reactid=".gvhr1sa3fw.0.1.2">',
#  '"https://www.bbc.co.uk/sport/sports-personality/50729382" class="top-story" data-reactid=".gvhr1sa3fw.0.1.2.$hp-ts-2"><div class="top-story__image-wrapper" data-reactid=".gvhr1sa3fw.0.1.2.$hp-ts-2.0"><div class="top-story__image" data-image-recipe="//ichef.bbci.co.uk/images/ic/$recipe/p07xs0vp.jpg" data-lazy="//ichef.bbci.co.uk/images/ic/384x216/p07xs0vp.jpg" data-reactid=".gvhr1sa3fw.0.1.2.$hp-ts-2.0.0"></div><noscript data-reactid=".gvhr1sa3fw.0.1.2.$hp-ts-2.0.$no-js"><div class="top-story__image top-story__image--fallback top-story__image--visible" style="background-image:url(//ichef.bbci.co.uk/images/ic/384x216/p07xs0vp.jpg);"></div></noscript></div><div class="top-story__content" data-reactid=".gvhr1sa3fw.0.1.2.$hp-ts-2.1"><h3 class="gel-pica-bold top-story__title-container" data-reactid=".gvhr1sa3fw.0.1.2.$hp-ts-2.1.0"><span class="top-story__title" data-reactid=".gvhr1sa3fw.0.1.2.$hp-ts-2.1.0.1">How well do you know your Sports Personality winners?</span></h3></div><span class="gel-minion top-story__attr-container" aria-labelledby="hp-ts-2-collection-more-top-stories" data-reactid=".gvhr1sa3fw.0.1.2.$hp-ts-2.2"><span id="hp-ts-2-collection-more-top-stories" data-reactid=".gvhr1sa3fw.0.1.2.$hp-ts-2.2.0"><span class="hp-accessibility-label" data-reactid=".gvhr1sa3fw.0.1.2.$hp-ts-2.2.0.0">From </span><span class="top-story__attr" data-reactid=".gvhr1sa3fw.0.1.2.$hp-ts-2.2.0.1">Sports Personality</span></span></span></a></div></div><script data-reactid=".gvhr1sa3fw.0.2">window.bbcIso = window.bbcIso || {}; window.bbcIso[\\\'top_stories_1576408247399_oe8n24pakxu4ts1vxa34vlsor\\\'] = {"title":"More top stories","newTag":false,"contentModel":{"topStories":[{"urn":"urn:bbc:homepagepromo:1fea930f245a6f146f815efa0b30157c","title":"Kelvin and Oti crowned Strictly winners","url":"https://www.bbc.co.uk/blogs/strictlycomedancing/entries/d34246b9-0ea4-49c0-9435-6a4c4910f708","image":{"templateUrl":"ichef.bbci.co.uk/images/ic/$recipe/p07xz79c.jpg","altText":null,"copyright":null},"attribution":"BBC One","assetType":"article","liveBadge":false,"promoTopic":"other","description":null,"cta":{}},{"urn":"urn:bbc:homepagepromo:5cc83fc2b7beb2a0d0de912963b0b0f1","title":"\\\'I was made to feel on the bottom of the food chain\\\'","url":"https://www.bbc.co.uk/bitesize/articles/zjtkbdm","image":{"templateUrl":"ichef.bbci.co.uk/images/ic/$recipe/p07kdqds.jpg","altText":null,"copyright":null},"attribution":"BBC Bitesize","assetType":"article","liveBadge":false,"promoTopic":"other","description":null,"cta":{}},{"urn":"urn:bbc:homepagepromo:7a3952f3536400333dd17aa8c18a7168","title":"How well do you know your Sports Personality winners?","url":"https://www.bbc.co.uk/sport/sports-personality/50729382","image":{"templateUrl":"ichef.bbci.co.uk/images/ic/$recipe/p07xs0vp.jpg","altText":null,"copyright":null},"attribution":"Sports Personality","assetType":"article","liveBadge":false,"promoTopic":"sport","description":null,"cta":{}}]},"maxStoriesToDisplay":3,"footer":{"url":""},"url":"","colorPalette":"default","template":"AllStoryThumbnail","moduleTheme":"darkTheme","imageTemplateUrl":"ichef.bbci.co.uk/images/ic/$recipe/$pid.jpg","isPaired":false,"backgroundImage":"p06xgdn4","talentBackgroundColour":"","refKey":"top_stories_1576408247399_oe8n24pakxu4ts1vxa34vlsor","fileId":"collection-more-top-stories","initialRenderHidden":false,"containerElementAttributes":{},"showVariant":false,"segmentationId":"","metVariantCriteria":false,"renderInitialImages":false,"talentSubtitle":"","talentImage":""};</script></div></div></section><section class="hp-module top-stories-container hp-module--duo hp-module--duo-all-thumbnails hp-module--light-theme" data-hp-interest="{&quot;id&quot;:&quot;latestnews&quot;,&quot;title&quot;:&quot;News headlines&quot;}" data-hp-banner-header-text="Interested in something else?"><div class="hp-module__container hp-module--light-theme" data-reference-key="top_stories_1576408280157_nwl0e39sj4dg4prreqgqlg14i" data-template="AllStoryThumbn ...
#  '"https://www.bbc.co.uk/news/election-2019-50799792" class="top-story" data-reactid=".6is8fppdlm.0.1.0.$hp-ts-0"><div class="top-story__image-wrapper" data-reactid=".6is8fppdlm.0.1.0.$hp-ts-0.0"><div class="top-story__image" data-image-recipe="//ichef.bbci.co.uk/curationkit-ichef/$recipe/cpsprodpb/11639/production/_110152217_92462dd0-ff3f-42b7-ac8b-c6e5c2cf2515.jpg" data-lazy="//ichef.bbci.co.uk/curationkit-ichef/384x216/cpsprodpb/11639/production/_110152217_92462dd0-ff3f-42b7-ac8b-c6e5c2cf2515.jpg" data-reactid=".6is8fppdlm.0.1.0.$hp-ts-0.0.0"></div><noscript data-reactid=".6is8fppdlm.0.1.0.$hp-ts-0.0.$no-js"><div class="top-story__image top-story__image--fallback top-story__image--visible" style="background-image:url(//ichef.bbci.co.uk/curationkit-ichef/384x216/cpsprodpb/11639/production/_110152217_92462dd0-ff3f-42b7-ac8b-c6e5c2cf2515.jpg);"></div></noscript></div><div class="top-story__content" data-reactid=".6is8fppdlm.0.1.0.$hp-ts-0.1"><h3 class="gel-pica-bold top-story__title-container" data-reactid=".6is8fppdlm.0.1.0.$hp-ts-0.1.0"><span class="top-story__title" data-reactid=".6is8fppdlm.0.1.0.$hp-ts-0.1.0.1">I own this disaster, says McDonnell</span></h3></div><span class="gel-minion top-story__attr-container" aria-labelledby="hp-ts-0-collection-latest-news" data-reactid=".6is8fppdlm.0.1.0.$hp-ts-0.2"><span id="hp-ts-0-collection-latest-news" data-reactid=".6is8fppdlm.0.1.0.$hp-ts-0.2.0"><span class="hp-accessibility-label" data-reactid=".6is8fppdlm.0.1.0.$hp-ts-0.2.0.0">From </span><span class="top-story__attr" data-reactid=".6is8fppdlm.0.1.0.$hp-ts-0.2.0.1">Election 2019</span></span></span></a></div><div class="top-story__wrapper gel-layout__item hp-bp-m-one-third top-story--small-image hp-ts--other" data-bbc-container="news headlines" data-bbc-content-id="https://www.bbc.co.uk/news/live/election-2019-50798916" data-bbc-content-label="Latest reaction to Tory win on Sunday shows" data-bbc-source="Election 2019" data-bbc-asset-type="article" data-bbc-personalisation="{&quot;EDN&quot;:&quot;uk&quot;}" data-bbc-metadata="{&quot;IMG&quot;:&quot;urn:bbc:imagepid:_110151076_mediaitem110151075&quot;}" data-reactid=".6is8fppdlm.0.1.1">',
#  '"https://www.bbc.co.uk/news/live/election-2019-50798916" class="top-story" data-reactid=".6is8fppdlm.0.1.1.$hp-ts-1"><div class="top-story__image-wrapper" data-reactid=".6is8fppdlm.0.1.1.$hp-ts-1.0"><div class="top-story__image" data-image-recipe="//ichef.bbci.co.uk/curationkit-ichef/$recipe/cpsprodpb/105C7/production/_110151076_mediaitem110151075.jpg" data-lazy="//ichef.bbci.co.uk/curationkit-ichef/384x216/cpsprodpb/105C7/production/_110151076_mediaitem110151075.jpg" data-reactid=".6is8fppdlm.0.1.1.$hp-ts-1.0.0"></div><noscript data-reactid=".6is8fppdlm.0.1.1.$hp-ts-1.0.$no-js"><div class="top-story__image top-story__image--fallback top-story__image--visible" style="background-image:url(//ichef.bbci.co.uk/curationkit-ichef/384x216/cpsprodpb/105C7/production/_110151076_mediaitem110151075.jpg);"></div></noscript></div><div class="top-story__content" data-reactid=".6is8fppdlm.0.1.1.$hp-ts-1.1"><h3 class="gel-pica-bold top-story__title-container" data-reactid=".6is8fppdlm.0.1.1.$hp-ts-1.1.0"><span class="hp-live-badge top-story__live-badge" data-reactid=".6is8fppdlm.0.1.1.$hp-ts-1.1.0.0"></span><span class="top-story__title" data-reactid=".6is8fppdlm.0.1.1.$hp-ts-1.1.0.1">Latest reaction to Tory win on Sunday shows</span><span class="hp-accessibility-label" data-reactid=".6is8fppdlm.0.1.1.$hp-ts-1.1.0.2">. Live now.</span></h3></div><span class="gel-minion top-story__attr-container" aria-labelledby="hp-ts-1-collection-latest-news" data-reactid=".6is8fppdlm.0.1.1.$hp-ts-1.2"><span id="hp-ts-1-collection-latest-news" data-reactid=".6is8fppdlm.0.1.1.$hp-ts-1.2.0"><span class="hp-accessibility-label" data-reactid=".6is8fppdlm.0.1.1.$hp-ts-1.2.0.0">From </span><span class="top-story__attr" data-reactid=".6is8fppdlm.0.1.1.$hp-ts-1.2.0.1">Election 2019</span></span></span></a></div><div class="top-story__wrapper gel-layout__item hp-bp-m-one-third top-story--small-image hp-ts--other" data-bbc-container="news headlines" data-bbc-content-id="https://www.bbc.co.uk/news/uk-50797374" data-bbc-content-label="British man shot dead in robbery in Argentina" data-bbc-source="Latin America &amp; Caribbean" data-bbc-asset-type="article" data-bbc-personalisation="{&quot;EDN&quot;:&quot;uk&quot;}" data-bbc-metadata="{&quot;IMG&quot;:&quot;urn:bbc:imagepid:_110150123_57618217-a8ca-4249-8e66-88c15fa571bb&quot;}" data-reactid=".6is8fppdlm.0.1.2">',
#  '"https://www.bbc.co.uk/news/uk-50797374" class="top-story" data-reactid=".6is8fppdlm.0.1.2.$hp-ts-2"><div class="top-story__image-wrapper" data-reactid=".6is8fppdlm.0.1.2.$hp-ts-2.0"><div class="top-story__image" data-image-recipe="//ichef.bbci.co.uk/curationkit-ichef/$recipe/cpsprodpb/7D69/production/_110150123_57618217-a8ca-4249-8e66-88c15fa571bb.jpg" data-lazy="//ichef.bbci.co.uk/curationkit-ichef/384x216/cpsprodpb/7D69/production/_110150123_57618217-a8ca-4249-8e66-88c15fa571bb.jpg" data-reactid=".6is8fppdlm.0.1.2.$hp-ts-2.0.0"></div><noscript data-reactid=".6is8fppdlm.0.1.2.$hp-ts-2.0.$no-js"><div class="top-story__image top-story__image--fallback top-story__image--visible" style="background-image:url(//ichef.bbci.co.uk/curationkit-ichef/384x216/cpsprodpb/7D69/production/_110150123_57618217-a8ca-4249-8e66-88c15fa571bb.jpg);"></div></noscript></div><div class="top-story__content" data-reactid=".6is8fppdlm.0.1.2.$hp-ts-2.1"><h3 class="gel-pica-bold top-story__title-container" data-reactid=".6is8fppdlm.0.1.2.$hp-ts-2.1.0"><span class="top-story__title" data-reactid=".6is8fppdlm.0.1.2.$hp-ts-2.1.0.1">British man shot dead in robbery in Argentina</span></h3></div><span class="gel-minion top-story__attr-container" aria-labelledby="hp-ts-2-collection-latest-news" data-reactid=".6is8fppdlm.0.1.2.$hp-ts-2.2"><span id="hp-ts-2-collection-latest-news" data-reactid=".6is8fppdlm.0.1.2.$hp-ts-2.2.0"><span class="hp-accessibility-label" data-reactid=".6is8fppdlm.0.1.2.$hp-ts-2.2.0.0">From </span><span class="top-story__attr" data-reactid=".6is8fppdlm.0.1.2.$hp-ts-2.2.0.1">Latin America &amp; Caribbean</span></span></span></a></div></div><script data-reactid=".6is8fppdlm.0.2">window.bbcIso = window.bbcIso || {}; window.bbcIso[\\\'top_stories_1576408280157_nwl0e39sj4dg4prreqgqlg14i\\\'] = {"title":"News headlines","newTag":false,"contentModel":{"topStories":[{"urn":"urn:bbc:cps:news:election-2019-50799792","title":"I own this disaster, says McDonnell","url":"https://www.bbc.co.uk/news/election-2019-50799792","image":{"templateUrl":"ichef.bbci.co.uk/curationkit-ichef/$recipe/cpsprodpb/11639/production/_110152217_92462dd0-ff3f-42b7-ac8b-c6e5c2cf2515.jpg","altText":"John McDonnell","copyright":"EPA"},"attribution":"Election 2019","assetType":"article","liveBadge":false,"promoTopic":"other","description":"The shadow chancellor says he is sorry for the \\\\"catastrophic\\\\" election result as Labour failed to get its messages across.","cta":{}},{"urn":"urn:bbc:cps:news:live:election-2019-50798916","title":"Latest reaction to Tory win on Sunday shows","url":"https://www.bbc.co.uk/news/live/election-2019-50798916","image":{"templateUrl":"ichef.bbci.co.uk/curationkit-ichef/$recipe/cpsprodpb/105C7/production/_110151076_mediaitem110151075.jpg","altText":"Prime Minister Boris Johnson and his partner Carrie Symonds enter Downing Street","copyright":"Getty Images"},"attribution":"Election 2019","assetType":"article","liveBadge":true,"promoTopic":"other","description":"Continuing coverage and reaction after the Conservatives\\\' victory in the general election.","cta":{}},{"urn":"urn:bbc:cps:news:uk-50797374","title":"British man shot dead in robbery in Argentina","url":"https://www.bbc.co.uk/news/uk-50797374","image":{"templateUrl":"ichef.bbci.co.uk/curationkit-ichef/$recipe/cpsprodpb/7D69/production/_110150123_57618217-a8ca-4249-8e66-88c15fa571bb.jpg","altText":"View of the facade of the Faena Hotel, in Puerto Madero neighbourhood, Buenos Aires","copyright":"AFP"},"attribution":"Latin America & Caribbean","assetType":"article","liveBadge":false,"promoTopic":"other","description":"The 50-year-old man and his son, who was wounded, were shot outside a luxury hotel in Buenos Aires.","cta":{}},{"urn":"urn:bbc:cps:news:election-2019-50799613","title":"Sturgeon: Scotland \\\'cannot be imprisoned\\\' in UK","url":"https://www.bbc.co.uk/news/election-2019-50799613","image":{"templateUrl":"ichef.bbci.co.uk/curationkit-ichef/$recipe/cpsprodpb/979F/production/ ...
# ...
#  '"https://www.bbc.co.uk/iplayer/episode/p07xkcgw/inside-cinema-2019-23-star-wardrobes" class="top-story" data-reactid=".1piakhjt5wi.0.1.1.$hp-ts-1"><div class="top-story__image-wrapper" data-reactid=".1piakhjt5wi.0.1.1.$hp-ts-1.0"><div class="top-story__image" data-image-recipe="//ichef.bbci.co.uk/images/ic/$recipe/p07xs2v5.jpg" data-lazy="//ichef.bbci.co.uk/images/ic/384x216/p07xs2v5.jpg" data-reactid=".1piakhjt5wi.0.1.1.$hp-ts-1.0.0"></div><noscript data-reactid=".1piakhjt5wi.0.1.1.$hp-ts-1.0.$no-js"><div class="top-story__image top-story__image--fallback top-story__image--visible" style="background-image:url(//ichef.bbci.co.uk/images/ic/384x216/p07xs2v5.jpg);"></div></noscript><span class="top-story__cta top-story__cta--video hp-cta--video" data-reactid=".1piakhjt5wi.0.1.1.$hp-ts-1.0.2"><span class="top-story__off-screen" data-reactid=".1piakhjt5wi.0.1.1.$hp-ts-1.0.2.0">Watch video</span></span></div><div class="top-story__content" data-reactid=".1piakhjt5wi.0.1.1.$hp-ts-1.1"><h3 class="gel-pica-bold top-story__title-container" data-reactid=".1piakhjt5wi.0.1.1.$hp-ts-1.1.0"><span class="top-story__title" data-reactid=".1piakhjt5wi.0.1.1.$hp-ts-1.1.0.1">What the costumes of a galaxy far, far away tell us</span></h3></div><span class="gel-minion top-story__attr-container" aria-labelledby="hp-ts-1-collection-things-we-loved-yesterday" data-reactid=".1piakhjt5wi.0.1.1.$hp-ts-1.2"><span id="hp-ts-1-collection-things-we-loved-yesterday" data-reactid=".1piakhjt5wi.0.1.1.$hp-ts-1.2.0"><span class="hp-accessibility-label" data-reactid=".1piakhjt5wi.0.1.1.$hp-ts-1.2.0.0">From </span><span class="top-story__attr" data-reactid=".1piakhjt5wi.0.1.1.$hp-ts-1.2.0.1">BBC Arts</span></span></span></a></div><div class="top-story__wrapper gel-layout__item hp-bp-m-one-third top-story--small-image hp-ts--other" data-bbc-container="you might have missed" data-bbc-content-id="https://www.bbc.co.uk/programmes/p07xn11x" data-bbc-content-label="Touching surprise for man after 20 Christmases alone" data-bbc-source="BBC One" data-bbc-asset-type="video" data-bbc-personalisation="{&quot;EDN&quot;:&quot;uk&quot;}" data-bbc-metadata="{&quot;IMG&quot;:&quot;urn:bbc:imagepid:p07xs4pk&quot;}" data-reactid=".1piakhjt5wi.0.1.2">',
#  '"https://www.bbc.co.uk/programmes/p07xn11x" class="top-story" data-reactid=".1piakhjt5wi.0.1.2.$hp-ts-2"><div class="top-story__image-wrapper" data-reactid=".1piakhjt5wi.0.1.2.$hp-ts-2.0"><div class="top-story__image" data-image-recipe="//ichef.bbci.co.uk/images/ic/$recipe/p07xs4pk.jpg" data-lazy="//ichef.bbci.co.uk/images/ic/384x216/p07xs4pk.jpg" data-reactid=".1piakhjt5wi.0.1.2.$hp-ts-2.0.0"></div><noscript data-reactid=".1piakhjt5wi.0.1.2.$hp-ts-2.0.$no-js"><div class="top-story__image top-story__image--fallback top-story__image--visible" style="background-image:url(//ichef.bbci.co.uk/images/ic/384x216/p07xs4pk.jpg);"></div></noscript><span class="top-story__cta top-story__cta--video hp-cta--video" data-reactid=".1piakhjt5wi.0.1.2.$hp-ts-2.0.2"><span class="top-story__off-screen" data-reactid=".1piakhjt5wi.0.1.2.$hp-ts-2.0.2.0">Watch video</span></span></div><div class="top-story__content" data-reactid=".1piakhjt5wi.0.1.2.$hp-ts-2.1"><h3 class="gel-pica-bold top-story__title-container" data-reactid=".1piakhjt5wi.0.1.2.$hp-ts-2.1.0"><span class="top-story__title" data-reactid=".1piakhjt5wi.0.1.2.$hp-ts-2.1.0.1">Touching surprise for man after 20 Christmases alone</span></h3></div><span class="gel-minion top-story__attr-container" aria-labelledby="hp-ts-2-collection-things-we-loved-yesterday" data-reactid=".1piakhjt5wi.0.1.2.$hp-ts-2.2"><span id="hp-ts-2-collection-things-we-loved-yesterday" data-reactid=".1piakhjt5wi.0.1.2.$hp-ts-2.2.0"><span class="hp-accessibility-label" data-reactid=".1piakhjt5wi.0.1.2.$hp-ts-2.2.0.0">From </span><span class="top-story__attr" data-reactid=".1piakhjt5wi.0.1.2.$hp-ts-2.2.0.1">BBC One</span></span></span></a></div></div><script data-reactid=".1piakhjt5wi.0.2">window.bbcIso = window.bbcIso || {}; window.bbcIso[\\\'top_stories_1576408273788_fd2qe610obyhds7s5p45f80k9\\\'] = {"title":"You might have missed","newTag":false,"contentModel":{"topStories":[{"urn":"urn:bbc:homepagepromo:3d1157c54f84e8531d1e6d93dcafbc95","title":"\\\'General election result feels like a dark cloud\\\'","url":"https://www.bbc.co.uk/news/newsbeat-50772708","image":{"templateUrl":"ichef.bbci.co.uk/images/ic/$recipe/p07xspyp.jpg","altText":null,"copyright":null},"attribution":"Newsbeat","assetType":"article","liveBadge":false,"promoTopic":"news","description":null,"cta":{}},{"urn":"urn:bbc:homepagepromo:2e70cc82e6d4cb126e870869eda052c5","title":"What the costumes of a galaxy far, far away tell us","url":"https://www.bbc.co.uk/iplayer/episode/p07xkcgw/inside-cinema-2019-23-star-wardrobes","image":{"templateUrl":"ichef.bbci.co.uk/images/ic/$recipe/p07xs2v5.jpg","altText":null,"copyright":null},"attribution":"BBC Arts","assetType":"video","liveBadge":false,"promoTopic":"other","description":null,"cta":{"type":"video","text":"Watch video"}},{"urn":"urn:bbc:homepagepromo:82600984d24d8cdfd1eb3ad9364a1307","title":"Touching surprise for man after 20 Christmases alone","url":"https://www.bbc.co.uk/programmes/p07xn11x","image":{"templateUrl":"ichef.bbci.co.uk/images/ic/$recipe/p07xs4pk.jpg","altText":null,"copyright":null},"attribution":"BBC One","assetType":"video","liveBadge":false,"promoTopic":"other","description":null,"cta":{"type":"video","text":"Watch video"}},{"urn":"urn:bbc:homepagepromo:1439d1711db8d29ca0ce19ab4f760ae7","title":"\\\'I order takeaways six nights a week\\\'","url":"https://www.bbc.co.uk/news/business-50742094","image":{"templateUrl":"ichef.bbci.co.uk/images/ic/$recipe/p07xmh6j.jpg","altText":null,"copyright":null},"attribution":"Business","assetType":"article","liveBadge":false,"promoTopic":"news","description":null,"cta":{}},{"urn":"urn:bbc:homepagepromo:45e10a7a7cdd58b5589ce88b6e5b26d1","title":"\\\'Our parents ran a secret gay porn empire\\\'","url":"https://www.bbc.co.uk/news/stories-50662998","image":{"templateUrl":"ichef.bbci.co.uk/images/ic/$recipe/p07xlk9s.jpg","altText":null,"copyright":null},"attribution":"Stories","assetType":"article","liveBadge":false,"promoTopic":"news","description":null,"c ...
#  '"http://www.bbc.com/scotland" class="hp-permanent-links__link"><span class="hp-permanent-links__link-name gel-brevier-bold">Scotland</span></a></li><li class="hp-permanent-links__item">',
#  '"http://www.bbc.com/alba" class="hp-permanent-links__link"><span class="hp-permanent-links__link-name gel-brevier-bold">ALBA</span></a></li><li class="hp-permanent-links__item">',
#  '"http://www.bbc.com/wales" class="hp-permanent-links__link"><span class="hp-permanent-links__link-name gel-brevier-bold">Wales</span></a></li><li class="hp-permanent-links__item">',
#  '"http://www.bbc.com/cymru" class="hp-permanent-links__link"><span class="hp-permanent-links__link-name gel-brevier-bold">Cymru</span></a></li><li class="hp-permanent-links__item">',
#  '"http://www.bbc.com/northernireland" class="hp-permanent-links__link"><span class="hp-permanent-links__link-name gel-brevier-bold">NI</span></a></li></ul></nav></div>\\n</section><section class="hp-module permanent-links-container" data-hp-interest="{}" data-hp-banner-header-text="Interested in something else?"><div class="hp-permanent-links" data-stats=""><h2 class="hp-permanent-links__title gel-brevier">Modern Slavery Statement</h2><nav class="hp-permanent-links__nav"><ul class="hp-permanent-links__links"><li class="hp-permanent-links__item">',
#  '" http://downloads.bbc.co.uk/aboutthebbc/reports/pdf/bbcmsa2019.pdf" class="hp-permanent-links__link"><span class="hp-permanent-links__link-name gel-brevier-bold">Read more</span></a></li></ul></nav></div>\\n</section><section class="hp-module permanent-links-container" data-hp-interest="{&quot;id&quot;:&quot;uknews&quot;,&quot;title&quot;:&quot;UK news&quot;}" data-hp-banner-header-text="Interested in something else?"><div class="hp-permanent-links" data-stats=""><h2 class="hp-permanent-links__title gel-brevier">Other services</h2><nav class="hp-permanent-links__nav"><ul class="hp-permanent-links__links"><li class="hp-permanent-links__item">',
#  '"http://www.bbc.co.uk/complaints/" class="hp-permanent-links__link"><span class="hp-permanent-links__link-name gel-brevier-bold">Complaints</span></a></li></ul></nav></div>\\n</section></div><div class="hp-dialogs-container"></div></div>\\n<div id="orb-footer" class="orb-footer" dir="ltr"><div id="navp-orb-footer-promo"></div><aside role="complementary"><div id="orb-aside" class="orb-nav-sec b-r b-g-p"><div class="orb-footer-inner" role="navigation" aria-label="BBC"><h2 class="orb-footer-lead">Explore the BBC</h2><div class="orb-footer-primary-links"><ul><li class="orb-nav-home">',
#  '"https://www.bbc.co.uk">Home</a></li><li class="orb-nav-news">',
#  '"https://www.bbc.co.uk/news">News</a></li><li class="orb-nav-sport">',
#  '"https://www.bbc.co.uk/sport">Sport</a></li><li class="orb-nav-weather">',
#  '"https://www.bbc.co.uk/weather">Weather</a></li><li class="orb-nav-iplayer">',
#  '"https://www.bbc.co.uk/iplayer">iPlayer</a></li><li class="orb-nav-sounds">',
#  '"https://www.bbc.co.uk/sounds">Sounds</a></li><li class="orb-nav-cbbc">',
#  '"https://www.bbc.co.uk/cbbc">CBBC</a></li><li class="orb-nav-cbeebies">',
#  '"https://www.bbc.co.uk/cbeebies">CBeebies</a></li><li class="orb-nav-food">',
#  '"https://www.bbc.co.uk/food">Food</a></li><li class="orb-nav-bitesize">',
#  '"https://www.bbc.co.uk/bitesize">Bitesize</a></li><li class="orb-nav-arts">',
#  '"https://www.bbc.co.uk/arts">Arts</a></li><li class="orb-nav-taster">',
#  '"https://www.bbc.co.uk/taster">Taster</a></li><li class="orb-nav-local">',
#  '"https://www.bbc.co.uk/news/localnews">Local</a></li><li class="orb-nav-tv">',
#  '"https://www.bbc.co.uk/tv">TV</a></li><li class="orb-nav-radio">',
#  '"https://www.bbc.co.uk/radio">Radio</a></li><li class="orb-nav-three">',
#  '"https://www.bbc.co.uk/bbcthree">Three</a></li></ul></div></div></div></aside><footer role="contentinfo"><div id="orb-contentinfo" class="orb-nav-sec b-r b-g-p"><script>window.orb.worldwideFooterlinks = \\\'<li class="orb-footer-ads">',
#  '"https://advertising.bbcworldwide.com/">Advertise with us<\\\'+\\\'/a><\\\'+\\\'/li><li class="orb-footer-adchoices">',
#  '"https://www.bbc.com/usingthebbc/cookies/how-does-the-bbc-use-cookies-for-advertising/">Ad choices<\\\'+\\\'/a><\\\'+\\\'/li>\\\';</script><div class="orb-footer-inner"> <ul><li class="orb-footer-terms">',
#  '"https://www.bbc.co.uk/usingthebbc/terms/">Terms of Use</a></li><li class="orb-footer-about">',
#  '"https://www.bbc.co.uk/aboutthebbc">About the BBC</a></li><li class="orb-footer-privacy">',
#  '"https://www.bbc.co.uk/usingthebbc/privacy/">Privacy Policy</a></li><li class="orb-footer-cookies">',
#  '"https://www.bbc.co.uk/usingthebbc/cookies/">Cookies</a></li><li class="orb-footer-accessibility">',
#  '"https://www.bbc.co.uk/accessibility/">Accessibility Help</a></li><li class="orb-footer-parental">',
#  '"https://www.bbc.co.uk/guidance">Parental Guidance</a></li><li class="orb-footer-contact">',
#  '"https://www.bbc.co.uk/contact">Contact the BBC</a></li><li class="orb-footer-newsletter">',
#  '"https://www.bbc.co.uk/bbcnewsletter">Get Personalised Newsletters</a></li></ul><small><em class="orb-hilight">Copyright &copy; 2019 BBC.</em> The BBC is not responsible for the content of external sites. <span class="orb-footer-links">',
#  '"https://www.bbc.co.uk/help/web/links/" class="orb-hilight">Read about our approach to external linking.</a></span></small></div></div></div></footer></div><script id="orb-js-script" data-assetpath="https://nav.files.bbci.co.uk/orbit/a07e26191aed6a8725358c88df999791/" src="https://nav.files.bbci.co.uk/orbit/a07e26191aed6a8725358c88df999791/js/orb.min.js"></script> <script type="text/javascript">require([\\\'orb/lib/_$\\\'], function($) {\\n        $.ready(function() {\\n            initialiseFooter();\\n        });\\n\\n        var scrollCheckTimer;\\n        var didScroll;\\n        var previousPosition = 0;\\n        var delta = 5;\\n        var PROMO_SHOW_BREAKPOINT = 1500;\\n        var pageLength = 0;\\n\\n        function initialiseFooter() {\\n            // Suppress this feature on browsers we no longer test\\n            var myNav = navigator.userAgent.toLowerCase();\\n            var oldIE = (myNav.indexOf(\\\'msie\\\') !== -1) && parseInt(myNav.split(\\\'msie\\\')[1], 10) <= 10;\\n            if (!oldIE) {\\n                require([\\\'orb/cookies\\\'], function (bbccookies) {\\n                    var disabledByCookie = (parseInt(bbccookies.get(\\\'ckns_nav_promofail\\\')) || 0) >= 3;\\n                    if (!disabledByCookie) {\\n                        require([\\\'orb/fig\\\'], function (orbFig) {\\n                            orbFig.load(function (fig) {\\n                                if (fig.geo.isUK()) {\\n                                    setUpLazyLoading();\\n                                }\\n                            });\\n                        });\\n                    }\\n                });\\n            }\\n        }\\n\\n        function setUpLazyLoading() {\\n            // offsetHeight is expensive to calculate, only do it once.\\n            pageLength = Math.abs(document.body.offsetHeight);\\n\\n            if (pageLength < getViewportHeight() + 300 || pageLength - getCurrentPosition() < PROMO_SHOW_BREAKPOINT) {\\n                loadPromo();\\n\\n            } else {\\n                window.onscroll = function () {\\n                    didScroll = true;\\n                };\\n\\n                scrollCheckTimer = setInterval(function () {\\n                    if (didScroll) {\\n                        hasScrolled();\\n                        didScroll = false;\\n                    }\\n                }, 250);\\n            }\\n        }\\n\\n        function loadPromo() {\\n            clearInterval(scrollCheckTimer);\\n\\n            require([\\\'orb/async/_footerpromo\\\'], function(promo) {\\n                promo.init(\\\'https://navpromo.api.bbci.co.uk\\\', \\\'\\\');\\n            });\\n        }\\n\\n        function getViewportHeight() {\\n            return window.innerHeight;\\n        }\\n\\n        function getCurrentPosition() {\\n            return Math.abs(window.scrollY || document.body.scrollTop || document.documentElement.scrollTop);\\n        }\\n\\n        function hasScrolled() {\\n            var currentPosition = getCurrentPosition();\\n            if (Math.abs(previousPosition - currentPosition) <= delta) {\\n                return;\\n            }\\n            if (currentPosition > previousPosition) {\\n                if ((pageLength - currentPosition) <= PROMO_SHOW_BREAKPOINT) {\\n                    loadPromo();\\n                }\\n            }\\n            previousPosition = currentPosition;\\n        }\\n\\n    })</script><script type="text/javascript">/*<![CDATA[*/\\n                require([\\\'orb/nav\\\'], function(nav) {\\n                    window.bbcuser.isUKCombined().then(function(isUK) {\\n                        if (isUK) {\\n                            nav.loadJs(\\\'https://nav.files.bbci.co.uk/orbit/a07e26191aed6a8725358c88df999791/js/edr.min.js\\\');\\n                        }\\n                    });\\n                });\\n            /*]]>*/</script><script type="text/javascript">require.config({\\n            paths: {\\n ...

# %%
parts[1:5]
# Out:
# ['"https://www.bbc.com/">Home</a></li><li class="orb-nav-newsdotcom">',
#  '"https://www.bbc.com/news">News</a></li><li class="orb-nav-sport">',
#  '"https://www.bbc.com/sport">Sport</a></li><li class="orb-nav-reeldotcom">',
#  '"https://www.bbc.com/reel">Reel</a></li><li class="orb-nav-worklife">']

# %%
for part in parts[1:5]:
    print(part.split('"')[1])
# Out:
# https://www.bbc.com/
# https://www.bbc.com/news
# https://www.bbc.com/sport
# https://www.bbc.com/reel

# %%
in_links=[]
parts=str(k).split("<a href=")
for part in parts:
    link=part.split('"')[1]
    if "www.bbc" not in link:pass
    else:
        in_links.append(link)
in_links
# Out:
# ['https://www.bbc.com/',
#  'https://www.bbc.com/news',
#  'https://www.bbc.com/sport',
#  'https://www.bbc.com/reel',
#  'https://www.bbc.com/worklife',
#  'https://www.bbc.com/travel',
#  'https://www.bbc.com/future',
#  'https://www.bbc.com/culture',
#  'https://www.bbc.com/culture/music',
#  'https://www.bbc.co.uk/schedules/p00fzl9m',
#  'https://www.bbc.com/weather',
#  'https://www.bbc.co.uk/sounds',
#  'https://www.bbc.co.uk',
#  'https://www.bbc.co.uk',
#  'https://www.bbc.co.uk/news',
#  'https://www.bbc.co.uk/sport',
#  'https://www.bbc.co.uk/weather',
#  'https://www.bbc.co.uk/iplayer',
#  'https://www.bbc.co.uk/sounds',
#  'https://www.bbc.co.uk/cbbc',
#  'https://www.bbc.co.uk/cbeebies',
#  'https://www.bbc.co.uk/food',
#  'https://www.bbc.co.uk/bitesize',
#  'https://www.bbc.co.uk/arts',
#  'https://www.bbc.co.uk/taster',
#  'https://www.bbc.co.uk/news/localnews',
#  'https://www.bbc.co.uk/tv',
#  'https://www.bbc.co.uk/radio',
#  'https://www.bbc.co.uk/bbcthree',
#  'https://www.bbc.co.uk/news/election-2019-50799792',
#  'https://www.bbc.co.uk/news/world-asia-50798205',
#  'https://www.bbc.co.uk/news/entertainment-arts-50763782',
#  'https://www.bbc.co.uk/news/live/election-2019-50798916',
#  'https://www.bbc.co.uk/news/newsbeat-50779961',
#  'https://www.bbc.co.uk/news/election-2019-50786212',
#  'https://www.bbc.co.uk/blogs/strictlycomedancing/entries/d34246b9-0ea4-49c0-9435-6a4c4910f708',
#  'https://www.bbc.co.uk/bitesize/articles/zjtkbdm',
#  'https://www.bbc.co.uk/sport/sports-personality/50729382',
#  'https://www.bbc.co.uk/news/election-2019-50799792',
#  'https://www.bbc.co.uk/news/live/election-2019-50798916',
#  'https://www.bbc.co.uk/news/uk-50797374',
#  'https://www.bbc.co.uk/sport/live/cricket/50423892',
#  'https://www.bbc.co.uk/sport/football/50797114',
#  'https://www.bbc.co.uk/sport/sports-personality/50757884',
#  'https://www.bbc.co.uk/programmes/p07xy9my',
#  'https://www.bbc.co.uk/programmes/p07xy5k6',
#  'https://www.bbc.co.uk/programmes/p07xy9pb',
#  'https://www.bbc.co.uk/programmes/p07xy3s8',
#  'https://www.bbc.co.uk/sounds/play/live:bbc_radio_three',
#  'https://www.bbc.co.uk/food/recipes/provenal_picnic_sandwich_20897',
#  'https://www.bbc.co.uk/news/uk-england-50747143',
#  'https://www.bbc.co.uk/sounds/play/m000c4wm',
#  'https://www.bbc.co.uk/programmes/p07xtm06',
#  'https://www.bbc.com/scotland',
#  'https://www.bbc.com/alba',
#  'https://www.bbc.com/wales',
#  'https://www.bbc.com/cymru',
#  'https://www.bbc.com/northernireland',
#  'https://www.bbc.co.uk/sport/av/sports-personality/50727410',
#  'https://www.bbc.co.uk/sport/sports-personality/50761473',
#  'https://www.bbc.co.uk/sport/av/sports-personality/50752816',
#  'https://www.bbc.co.uk/sounds/play/p07xwwsr',
#  'https://www.bbc.co.uk/news/entertainment-arts-50792979',
#  'https://www.bbc.co.uk/news/entertainment-arts-50762653',
#  'https://www.bbc.co.uk/programmes/p07xsl4b',
#  'https://www.bbc.co.uk/blogs/writersroom/entries/b7167122-5442-4b29-a66a-7b957c80fe0c',
#  'https://www.bbc.co.uk/programmes/p07xnpn8',
#  'https://www.bbc.co.uk/iplayer/episode/m000cfv8',
#  'https://www.bbc.co.uk/iplayer/episode/p07vzgp0',
#  'https://www.bbc.co.uk/iplayer/episode/m000cf8q',
#  'https://www.bbc.co.uk/iplayer/episode/b018xtm1',
#  'https://www.bbc.co.uk/iplayer/episode/b03pd6bf',
#  'https://www.bbc.co.uk/iplayer/episode/p07vb2ny',
#  'https://www.bbc.co.uk/programmes/articles/245nNStH3jljGJZNW9DLP1j/what-you-need-to-know-if-you-re-facing-dismissal-at-work',
#  'https://www.bbc.co.uk/news/business-50792986',
#  'https://www.bbc.co.uk/sounds/play/p07xnfd7',
#  'https://www.bbc.co.uk/food/collections/edible_gifts',
#  'https://www.bbc.co.uk/food/collections/winter_stews',
#  'https://www.bbc.co.uk/food/collections/time_saving_recipe_hacks',
#  'https://www.bbc.com/ideas/videos/when-motorway-services-were-the-height-of-cool/p07s1mhl?playlist=leisure-and-pleasure',
#  'https://www.bbc.co.uk/sounds/play/p07xp2m7',
#  'https://www.bbc.com/ideas/videos/why-are-people-sexist/p07xkbmq',
#  'https://www.bbc.co.uk/news/world-us-canada-50785442',
#  'https://www.bbc.co.uk/news/stories-49939123',
#  'https://www.bbc.co.uk/news/world-asia-50790481',
#  'https://www.bbc.co.uk/sport/av/football/50796819',
#  'https://www.bbc.co.uk/sport/golf/50792779',
#  'https://www.bbc.co.uk/sport/football/50788473',
#  'https://www.bbc.co.uk/news/newsbeat-50772708',
#  'https://www.bbc.co.uk/iplayer/episode/p07xkcgw/inside-cinema-2019-23-star-wardrobes',
#  'https://www.bbc.co.uk/programmes/p07xn11x',
#  'http://www.bbc.com/scotland',
#  'http://www.bbc.com/alba',
#  'http://www.bbc.com/wales',
#  'http://www.bbc.com/cymru',
#  'http://www.bbc.com/northernireland',
#  'http://www.bbc.co.uk/complaints/',
#  'https://www.bbc.co.uk',
#  'https://www.bbc.co.uk/news',
#  'https://www.bbc.co.uk/sport',
#  'https://www.bbc.co.uk/weather',
#  'https://www.bbc.co.uk/iplayer',
#  'https://www.bbc.co.uk/sounds',
#  'https://www.bbc.co.uk/cbbc',
#  'https://www.bbc.co.uk/cbeebies',
#  'https://www.bbc.co.uk/food',
#  'https://www.bbc.co.uk/bitesize',
#  'https://www.bbc.co.uk/arts',
#  'https://www.bbc.co.uk/taster',
#  'https://www.bbc.co.uk/news/localnews',
#  'https://www.bbc.co.uk/tv',
#  'https://www.bbc.co.uk/radio',
#  'https://www.bbc.co.uk/bbcthree',
#  'https://www.bbc.com/usingthebbc/cookies/how-does-the-bbc-use-cookies-for-advertising/',
#  'https://www.bbc.co.uk/usingthebbc/terms/',
#  'https://www.bbc.co.uk/aboutthebbc',
#  'https://www.bbc.co.uk/usingthebbc/privacy/',
#  'https://www.bbc.co.uk/usingthebbc/cookies/',
#  'https://www.bbc.co.uk/accessibility/',
#  'https://www.bbc.co.uk/guidance',
#  'https://www.bbc.co.uk/contact',
#  'https://www.bbc.co.uk/bbcnewsletter',
#  'https://www.bbc.co.uk/help/web/links/']

# %%
len(in_links)
# Out:
# 123

# %%
in_links=set(in_links)
len(in_links)
# Out:
# 103

# %% [markdown]
# ### Accessing google search with urllib

# %%
url='https://www.google.com/search?q=python+programming+tutorials'
resp = urlopen(url)
respData = resp.read()
print(respData)
# Out:
# -------------------------------------------------------------------
# HTTPError                         Traceback (most recent call last)
# <ipython-input-12-def9af159282> in <module>
#       1 url='https://www.google.com/search?q=python+programming+tutorials'
# ----> 2 resp = urlopen(url)
#       3 respData = resp.read()
#       4 print(respData)
#
# /anaconda3/envs/tutor/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /anaconda3/envs/tutor/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# /anaconda3/envs/tutor/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# /anaconda3/envs/tutor/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# /anaconda3/envs/tutor/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /anaconda3/envs/tutor/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %%
from urllib.request import Request
url = 'https://www.google.com/search?q=python+programming+tutorials'

headers = {}
headers['User-Agent'] = r"Mozilla/5.0 (X11; Linux i686) AppleWebKit/537.17 (KHTML, like Gecko) Chrome/24.0.1312.27 Safari/537.17"

req = Request(url, headers = headers)
resp = urlopen(req)
respData = resp.read()

# %%
print(respData)
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="en-IN"><head><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><meta content="origin" name="referrer"><title>python programming tutorials - Google Search</title><script nonce="405LN45LUmq2aeNmU5ARPw==">(function(){window.google={kEI:\'DRf2XaabKtferQGymaSoBA\',kEXPI:\'31\',authuser:0,kscs:\'c9c918f0_DRf2XaabKtferQGymaSoBA\',kGL:\'IN\',kBL:\'9hVE\'};google.sn=\'web\';google.kHL=\'en-IN\';google.jsfs=\'Ffpdje\';})();(function(){google.lc=[];google.li=0;google.getEI=function(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||google.kEI};google.getLEI=function(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b};google.https=function(){return"https:"==window.location.protocol};google.ml=function(){return null};google.time=function(){return(new Date).getTime()};google.log=function(a,b,e,c,g){if(a=google.logUrl(a,b,e,c,g)){b=new Image;var d=google.lc,f=google.li;d[f]=b;b.onerror=b.onload=b.onabort=function(){delete d[f]};google.vel&&google.vel.lu&&google.vel.lu(a);b.src=a;google.li=f+1}};google.logUrl=function(a,b,e,c,g){var d="",f=google.ls||"";e||-1!=b.search("&ei=")||(d="&ei="+google.getEI(c),-1==b.search("&lei=")&&(c=google.getLEI(c))&&(d+="&lei="+c));c="";!e&&google.cshid&&-1==b.search("&cshid=")&&"slh"!=a&&(c="&cshid="+google.cshid);a=e||"/"+(g||"gen_204")+"?atyp=i&ct="+a+"&cad="+b+d+f+"&zx="+google.time()+c;/^http:/i.test(a)&&google.https()&&(google.ml(Error("a"),!1,{src:a,glmm:1}),a="");return a};}).call(this);(function(){google.y={};google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};}).call(this);google.f={};(function(){document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);}).call(this);(function(){google.hs={h:true,sie:false};})();var k="function"==typeof Object.defineProperties?Object.defineProperty:function(a,e,c){a!=Array.prototype&&a!=Object.prototype&&(a[e]=c.value)},l="undefined"!=typeof window&&window===this?this:"undefined"!=typeof global&&null!=global?global:this,m=function(a,e){if(e){for(var c=l,b=a.split("."),f=0;f<b.length-1;f++){var d=b[f];d in c||(c[d]={});c=c[d]}b=b[b.length-1];f=c[b];d=e(f);d!=f&&null!=d&&k(c,b,{configurable:!0,writable:!0,value:d})}};m("String.prototype.startsWith",function(a){return a?a:function(e,c){if(null==this)throw new TypeError("The \'this\' value for String.prototype.startsWith must not be null or undefined");if(e instanceof RegExp)throw new TypeError("First argument to String.prototype.startsWith must not be a regular expression");var b=this+"";e+="";for(var f=b.length,d=e.length,h=Math.max(0,Math.min(c|0,b.length)),g=0;g<d&&h<f;)if(b[h++]!=e[g++])return!1;return g>=d}});google.arwt=function(a){a.href=document.getElementById(a.id.substring(a.id.startsWith("vcs")?3:1)).href;return!0};(function(){var f=this||self,g=Date.now||function(){return+new Date};var y={};var aa=function(a,c){if(null===c)return!1;if("contains"in a&&1==c.nodeType)return a.contains(c);if("compareDocumentPosition"in a)return a==c||!!(a.compareDocumentPosition(c)&16);for(;c&&a!=c;)c=c.parentNode;return c==a};var ba=function(a,c){return function(d){d||(d=window.event);return c.call(a,d)}},A=function(a){a=a.target||a.srcElement;!a.getAttribute&&a.parentNode&&(a=a.parentNode);return a},B="undefined"!=typeof navigator&&/Macintosh/.test(navigator.userAgent),ca="undefined"!=typeof navigator&&!/Opera/.test(navigator.userAgent)&&/WebKit/.test(navigator.userAgent),da={A:1,INPUT:1,TEXTAREA:1,SELECT:1,B ...

# %% [markdown]
# ### Parsing with BeautifulSoup

# %%
from bs4 import BeautifulSoup

# %%
mydata=urlopen("https://in.finance.yahoo.com/q?s=SBIN.BO").read()
soup = BeautifulSoup(mydata,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html class="NoJs featurephone" id="atomic" lang="en-IN"><head prefix="og: http://ogp.me/ns#"><script>window.performance && window.performance.mark && window.performance.mark('PageStart');</script><meta charset="utf-8"/><title>STATE BANK OF INDIA (SBIN.BO) Stock Price, Quote, History &amp; News - Yahoo Finance</title><meta content="SBIN.BO, STATE BANK OF INDIA, SBIN.BO stock chart, STATE BANK OF INDIA stock chart, stock chart, stocks, quotes, finance" name="keywords"/><meta content="on" http-equiv="x-dns-prefetch-control"/><meta content="on" property="twitter:dnt"/><meta content="131747896861126" property="fb:app_id"/><meta content="#400090" name="theme-color"/><meta content="width=device-width, initial-scale=1" name="viewport"/><meta content="Find the latest STATE BANK OF INDIA (SBIN.BO) stock quote, history, news and other vital information to help you with your stock trading and investing." lang="en-IN" name="description"/><meta content="guce.yahoo.com" name="oath:guce:consent-host"/><meta content="A9862C0E6E1BE95BCE0BF3D0298FD58B" name="msvalidate.01"/><link href="/manifest.json" rel="manifest"/><link href="//l.yimg.com" rel="dns-prefetch"/><link href="//s.yimg.com" rel="dns-prefetch"/><link href="//csc.beap.bc.yahoo.com" rel="dns-prefetch"/><link href="//geo.query.yahoo.com" rel="dns-prefetch"/><link href="//y.analytics.yahoo.com" rel="dns-prefetch"/><link href="//b.scorecardresearch.com" rel="dns-prefetch"/><link href="//iquery.finance.yahoo.com" rel="dns-prefetch"/><link href="//fc.yahoo.com" rel="dns-prefetch"/><link href="//video-api.yql.yahoo.com" rel="dns-prefetch"/><link href="//yrtas.btrll.com" rel="dns-prefetch"/><link href="//shim.btrll.com" rel="dns-prefetch"/><link href="//consent.cmp.oath.com" rel="dns-prefetch"/><link href="//geo.yahoo.com" rel="dns-prefetch"/><link crossorigin="anonymous" href="//l.yimg.com" rel="preconnect"/><link crossorigin="anonymous" href="//s.yimg.com" rel="preconnect"/><link href="//csc.beap.bc.yahoo.com" rel="preconnect"/><link href="//geo.query.yahoo.com" rel="preconnect"/><link href="//y.analytics.yahoo.com" rel="preconnect"/><link href="//b.scorecardresearch.com" rel="preconnect"/><link href="//iquery.finance.yahoo.com" rel="preconnect"/><link href="//fc.yahoo.com" rel="preconnect"/><link href="//video-api.yql.yahoo.com" rel="preconnect"/><link href="//yrtas.btrll.com" rel="preconnect"/><link href="//shim.btrll.com" rel="preconnect"/><link href="//consent.cmp.oath.com" rel="preconnect"/><link href="//geo.yahoo.com" rel="preconnect"/><link href="//ads.yahoo.com" rel="preconnect"/><link href="/_finStreamer-worker.js" rel="preload"/><link href="/_rapidworker-1.2.js" rel="preload"/><link href="https://s.yimg.com/cv/apiv2/default/icons/favicon_y19_32x32_custom.svg" rel="icon" sizes="any"/><link href="https://s.yimg.com/cv/apiv2/default/fp/20180826/icons/favicon_y19_32x32.ico" rel="alternate icon" type="image/x-icon"/><link href="https://in.finance.yahoo.com/quote/SBIN.BO/" rel="canonical"/><meta content="@YahooIndia" property="twitter:site"/><meta content="131747896861126" property="fb:pages"/><meta content="https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo.png" property="og:image"/><meta content="Find the latest STATE BANK OF INDIA (SBIN.BO) stock quote, history, news and other vital information to help you with your stock trading and investing." property="og:description"/><meta content="STATE BANK OF INDIA (SBIN.BO) Stock Price, Quote, History &amp; News - Yahoo Finance" property="og:title"/><meta content="Find the latest STATE BANK OF INDIA (SBIN.BO) stock quote, history, news and other vital information to help you with your stock trading and investing." property="twitter:description"/><meta content="STATE BANK OF INDIA (SBIN.BO) Stock Price, Quote, History &amp; News - Yahoo Finance" property="twitter:title"/><meta content="yfinance://quote/SBIN.BO" property="al:ios:url"/><meta content="328412701" property="al:ios:app_store_id"/><meta content="Yahoo Finance" property=" ...
# if (!window.YAHOO || !window.YAHOO.i13n || !window.YAHOO.i13n.Rapid) { return; }
# var rapidConfig = {"async_all_clicks":true,"click_timeout":300,"client_only":1,"compr_type":"deflate","keys":{"ver":"ydotcom","navtype":"server","pt":"utility","pct":"qsp","pstcat":"equities","pg_name":"summary","rvt":"SBIN.BO","ticker":"SBIN.BO","ccode_st":"finance-frontpage","mrkt":"in","site":"finance","lang":"en-IN","colo":"sg3","_yrid":"94n8a6pevc5v3","_rid":"94n8a6pevc5v3","abk":""},"pageview_on_init":true,"query_parameters":true,"test_id":"finance-IN-en-IN-def","tracked_mods_viewability":[],"track_right_click":true,"viewability":true,"dwell_on":true,"perf_navigationtime":2,"perf_resourcetime":1,"webworker_file":"/__rapidworker-1.2.js","spaceid":985404724};
# window.rapidInstance = new window.YAHOO.i13n.Rapid(rapidConfig);
# })();</script></head><body><div id="app"><div class="" data-react-checksum="-300493233" data-reactid="1" data-reactroot=""><div data-reactid="2"><div class="render-target-active render-target-default" data-reactid="3" id="render-target-default"><div class="finance IN en-IN H(100%) uh-search-open_Ovy(h) uh-search-open_H(100vh)" data-reactid="4"><div class="YDC-MainCanvas Bgc($bg-body) Mih(100%)" data-reactid="5" id="YDC-MainCanvas" style="padding-top:54px;margin-bottom:auto;"><div class="YDC-UH lw-nav-open_D(n)" data-reactid="6" id="YDC-UH" style="height:54px;"><div class="YDC-UH-Stack Z(10) End(0) Start(0) T(0) Pos(f) uh-search-open_Pos(a) uh-mobile-nav-open_D(n) lw-nav-open_D(n)" data-reactid="7" id="YDC-UH-Stack"><div data-reactid="8" id="YDC-UH-Stack-Composite"><div data-reactid="9"><div data-locator="subtree-root" id="mrt-node-UH-0-UH"><div data-react-checksum="-258753280" data-reactid="1" data-reactroot="" id="UH-0-UH-Proxy"><div data-reactid="2"><div data-reactid="3"><div class="C(#fff) Fz(13px) H(22px)" data-reactid="4" id="masterNav"><ul class="H(22px) Lh(1.7) M(0) NavLinks P(0) Whs(nw) Z(11) Bgc(#2d1152) Pos(a) Start(0) End(0)" data-reactid="5" id="eyebrow" role="navigation"><!-- react-empty: 6 --></ul></div><div class="Miw(980px) UH Z(10) Py(14px) Pos(r)" data-name="tdv2-applet-uh" data-reactid="7" data-version="10.2.7" id="UH-0-UH-0-Header"><div data-reactid="8"><div class="Fl(start) Fz(0) M(0) P(0) ie-7_W(190px) Miw(190px) UHMR1D_Py(0)" data-reactid="9" style="background-color:transparent;"><div data-reactid="10"><style data-reactid="11">#UH-0-UH-0-Header #uh-logo {background-image: url(https://s1.yimg.com/rz/d/yahoo_finance_en-IN_s_f_pw_351x40_finance.png);} @media  only screen and ( -webkit-min-device-pixel-ratio: 2 ), only screen and ( min--moz-device-pixel-ratio: 2), only screen and ( -o-min-device-pixel-ratio: 2/1), only screen and ( min-device-pixel-ratio: 2), only screen and ( min-resolution: 192dpi), only screen and ( min-resolution: 2dppx), only screen and ( min-aspect-ratio: 2/1 ) { #UH-0-UH-0-Header #uh-logo {background-image: url(https://s1.yimg.com/rz/d/yahoo_finance_en-IN_s_f_pw_351x40_finance_2x.png);} }</style><a class="Bgpx(0) Bgr(nr) Cur(p) D(b) H(35px) Bgz(702px) Mx(a)! W(92px)" data-reactid="12" href="https://in.finance.yahoo.com/" id="uh-logo"><b class="Hidden" data-reactid="13">Yahoo</b></a></div></div><div class="Bdrs(3px) D(b) Start(0) W(100%) Z(4)" data-reactid="14" id="uh-search"><form action="/quote/" class="M(0) P(0) Whs(nw)" data-reactid="15" method="get" name="input"><label class="Hidden" data-reactid="16" for="fin-srch-assist">Search</label><div class="" data-reactid="17"><div class="Z(2) Pos(r) IbBox uh-search-open_W($srchInputTouchDeviceWidth) W(100%)" data-reactid="18" id="fin-srch-assist"><input aria-label="Search" autocapitalize="off" autocomplete="off" autocorrect="off" class="Pos(r) W(100%) H(35px) M(0) O(0) O(0):f Bgc(white) Z(2) Bxsh(n) Bxsh(n):f Pt(6px) Pb(8px) Pstart(36px) Pend(20px) Va(t) Bd(0) Bdrs(2px) Fz(16px)" data-reactid="19" id="yfin-usr-qry" maxlength="4096" name="yfin-usr-qry" placeholder="Search for news, symbols or companies" type="text" value=""/><div class="Z(2) Pos(a) Start(8px) T(8px)" data-reactid="20"><svg class="H(20px) W(20px) Va(m)! Fill($finDarkGray)! Stk($finDarkGray) Cur(p)" data-icon="search" data-reactid="21" height="20" style="fill:#000;stroke:#000;stroke-width:0;vertical-align:bottom;" viewbox="0 0 24 24" width="20"><path d="M9 3C5.686 3 3 5.686 3 9c0 3.313 2.686 6 6 6s6-2.687 6-6c0-3.314-2.686-6-6-6m13.713 19.713c-.387.388-1.016.388-1.404 0l-7.404-7.404C12.55 16.364 10.85 17 9 17c-4.418 0-8-3.582-8-8 0-4.42 3.582-8 8-8s8 3.58 8 8c0 1.85-.634 3.55-1.69 4.905l7.403 7.404c.39.386.39 1.015 0 1.403" data-reactid="22"></path></svg></div><div class="Pos(a) Z(2) End(0) T(0)" data-reactid="23"></div></div><script data-reactid="24">(function () {
#         var inputEl = document.getElementById('yfin-usr-qry');
#         var perf = window.performance;
#         if (inputEl && inputEl.addEventListener && perf && perf.mark && perf.getEntriesByName) {
#             var listener = function (e) {
#                 inputEl.removeEventListener('keyup', listener);
#                 if (perf.getEntriesByName('Fin.Search first keyup').length === 0) {
#                     perf.mark('Fin.Search first keyup');
#                 }
#             };
#             inputEl.addEventListener('keyup', listener);
#         }
#     })();</script><div class="Pos(a) Ta(start) Start(0) End(0) Bgc(white) Z(1) Wob(ba) Whs(n) Bxsh($boxShadow) D(n) Mt(8px) Bd(0)" data-reactid="25" data-test="search-assist-input-sugglst"><div class="M(0) Pb(5px) Bxsh($boxShadow) Bdrsbend(3px) Bdrsbstart(3px)" data-reactid="26"><div class="Mb(10px) Pt(40px) Ta(c)" data-reactid="27"><svg class="H(20px) W(20px) Mend(10px) Va(m)! Fill($finDarkGray)! Stk($finDarkGray) Cur(a)! Cur(p)" data-icon="attention" data-reactid="28" height="20" style="fill:#000;stroke:#000;stroke-width:0;vertical-align:bottom;" viewbox="0 0 48 48" width="20"><path d="M24.993 46.424c-12.13 0-22-9.87-22-22s9.87-22 22-22 22 9.87 22 22-9.87 22-22 22zm0-40c-9.925 0-18 8.075-18 18 0 9.926 8.075 18 18 18s18-8.074 18-18c0-9.924-8.075-18-18-18zM24.993 27.424c-1.104 0-2-.895-2-2v-10c0-1.104.896-2 2-2s2 .896 2 2v10c0 1.105-.895 2-2 2zM22.993 33.424a2 2 0 1 0 4 0 2 2 0 1 0-4 0z" data-reactid="29"></path></svg></div><div class="C($finDarkGray) Fw(500) Fz(m) Ta(c) Pb(40px) Px(20px)" data-reactid="30"><span data-reactid="31">No matching results for ''</span></div></div><div class="Ta(start) C($finDarkGray) Fz(s) Fz(500) D(b) Py(8px) Pstart(20px)" data-reactid="32"><span data-reactid="33">Tip: Try a valid symbol or a specific company name for relevant results</span></div></div><button class="C(white) Bd(0) Fw(500) Fz(s) Px(10px) Py(5px) Ta(c) uh-search-open_D(ib) D(n) Va(m) H(35px) Fl(end)" data-reactid="34" type="button"><div class="Ell D(ib) Maw(80px)" data-reactid="35"><span data-reactid="36">Cancel</span></div></button></div><input data-reactid="37" name="fr" type="hidden" value="uh3_finance_vert"/><input data-reactid="38" name="fr2" type="hidden" value="p:finvsrp,m:sb"/><input data-reactid="39" name=".tsrc" type="hidden" value=""/></form></div><ul class="End(20px) List(n) Pos(a) T(14px)" data-reactid="40" id="uh-right"><li class="Fl(start) Mx(4px) Mend(9px) V(h)" data-reactid="41"><svg class="Cur(p)" data-icon="profile" data-reactid="42" height="34" style="fill:#400090;stroke:#400090;stroke-width:0;vertical-align:bottom;" viewbox="0 0 48 48" width="34"><path d="M4.095 33.61c1.092 2.7 2.607 4.937 4.562 6.696 1.94 1.766 4.23 3.072 6.847 3.922 2.632.846 5.472 1.27 8.53 1.27 3.012 0 5.837-.425 8.458-1.27 1.053-.342 2.046-.754 2.986-1.244 1.41-.732 2.705-1.617 3.87-2.678 1.948-1.76 3.472-3.996 4.558-6.697 1.092-2.7 1.636-5.903 1.636-9.614 0-3.702-.544-6.904-1.636-9.61-1.086-2.703-2.608-4.934-4.56-6.694-1.944-1.767-4.23-3.07-6.854-3.922-2.62-.847-5.445-1.27-8.457-1.27-3.06 0-5.9.423-8.53 1.27-.847.277-1.662.607-2.443.98-1.623.777-3.1 1.753-4.404 2.942-1.956 1.76-3.47 3.992-4.562 6.694-1.09 2.706-1.636 5.908-1.636 9.61-.002 3.71.545 6.914 1.635 9.613zM35.838 34.758l-23.674.002v-2.21s.017-1.425 3.123-2.716c1.538-.633 3.35-1.854 6.6-2.24-.997-.705-1.44-2.154-2.29-4.17-.02-.032-.03-.068-.043-.1-.193.032-.393.032-.537-.046-.398-.232-.636-1.48-.642-2.092-.01-.906.48-.824.48-.824s.017 0 .042-.004c-.006-.07-.01-.142-.01-.213 0-.86-.174-2.24.053-2.988.353-1.176.78-2.46 1.72-2.464.874 0 .28-1.006 1.348-1.345 1.102-.348 2.912.262 3.283.262.53 0 1.863.378 2.78 1.284.646.64.572 1.08.93 2.25.23.777.057 2.167.057 3 0 .07-.007.14-.014.213.018.007.03.007.03.007s.487-.082.478.824c-.004.612-.248 1.86-.635 2.092-.146.078-.34.078-.53.052-.01.026-.023.058-.033.09-.85 1.996-1.308 3.457-2.305 4.162 3.283.38 5.107 1.61 6.654 2.25 3.128 1.287 3.14 2.533 3.14 2.533l-.002 2.39z" data-reactid="43"></path></svg></li><li class="D(ib) Mstart(14px) Mt(-1px) ua-ie8_Pb(10px) ua-ie9_Pb(10px)" data-reactid="44"><a class="Pos(r) D(ib) Ta(s) Td(n):h" data-reactid="45" href="https://mail.yahoo.com/?.intl=in&amp;.lang=en-IN&amp;.partner=none&amp;.src=finance" id="uh-mail"><svg class="Cur(p)" data-icon="NavMail" data-reactid="46" height="35" style="fill:#400090;stroke:#400090;stroke-width:0;vertical-align:bottom;" viewbox="0 0 512 512" width="30"><path d="M460.586 91.31H51.504c-10.738 0-19.46 8.72-19.46 19.477v40.088l224 104.03 224-104.03v-40.088c0-10.757-8.702-19 ...
# window._adPerfData = [];
# window._adPosMsg = [];
# window._perfMark = function _perfMark (name) {if (window.performance && window.performance.mark){try {if (window.performance.getEntriesByName("NAVIGATE_START") && window.performance.getEntriesByName("NAVIGATE_START")[0]) { name = "CL_" + name ;}window.performance.mark(name);} catch (e) {console.warn(name + ' could not be marked:',e);}};};
# window._perfMeasure = function _perfMeasure (name, start, end) {if (window.performance && window.performance.measure){try {if (window.performance.getEntriesByName("NAVIGATE_START") && window.performance.getEntriesByName("NAVIGATE_START")[0]) { start = "CL_" + start ;end = "CL_" + end ;name = "CL_" + name ;}window.performance.measure(name, start, end);} catch (e) {console.warn(name + ' could not be added:',e);}};};
# window._pushAdPerfMetric = function _pushAdPerfMetric(key) {if (window.performance && window.performance.now) {_adPerfData.push([key, Math.round(window.performance.now())]);}};
# window._fireAdPerfBeacon = function _fireAdPerfBeacon(eventName) {try {if (window && window.rapidInstance && window.performance) {var navClickMark = window.performance.getEntriesByName('NAVIGATE_START') &&window.performance.getEntriesByName('NAVIGATE_START').pop();var navClickTime = navClickMark && navClickMark.startTime || 0;var userTime = {};window.performance.getEntries().forEach(function forEachPerfTime (item) {if (item.name.search('DARLA_') > -1) {if (item.entryType === "mark") {userTime[item.name] = Math.round(item.startTime) - navClickTime;window.performance.clearMarks(item.name);} else if (item.entryType === "measure") {userTime[item.name] = Math.round(item.duration);window.performance.clearMeasures(item.name);}}});var perfData = {perf_usertime: {utm: userTime}};
# window.rapidInstance.beaconPerformanceData(perfData);}} catch (e) {console.warn('Could not send the beacon:',e);}};
# window.DARLA_CONFIG = {"debug":false,"dm":1,"autoRotation":10000,"rotationTimingDisabled":true,"k2":{"res":{"rate":5,"pos":["BTN","BTN-1","BTN-2","BTN-3","BTN1","LREC","LREC2","LREC3","LDRB","MAST"]}},"positions":{"DEFAULT":{"name":"DEFAULT","enable":true,"fallback":null,"metaSize":false,"staticLayout":false,"clean":"defaultcleanDEFAULT","dest":"defaultdestDEFAULT","id":"DEFAULT","meta":{"hostURL":"https://in.finance.yahoo.com/quote/SBIN.BO"}},"WPS":{"id":"WPS","clean":"defaultcleanWPS","dest":"defaultdestWPS","metaSize":true,"w":320,"h":50,"enable":true,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://in.finance.yahoo.com/quote/SBIN.BO"}},"BTN1":{"id":"BTN1","clean":"defaultcleanBTN1","dest":"defaultdestBTN1","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://in.finance.yahoo.com/quote/SBIN.BO"}},"BTN1-1":{"id":"BTN1","clean":"defaultcleanBTN1-1","dest":"defaultdestBTN1-1","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://in.finance.yahoo.com/quote/SBIN.BO"}},"BTN":{"id":"BTN","clean":"defaultcleanBTN","dest":"defaultdestBTN","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://in.finance.yahoo.com/quote/SBIN.BO"}},"BTN-1":{"id":"BTN-1","clean":"defaultcleanBTN-1","dest":"defaultdestBTN-1","w":120,"h":60,"enable":false,"fallback":null,"metaSize":false,"staticLayout":false,"meta":{"hostURL":"https://in.finance.yahoo.com/quote/SBIN.BO"}},"BTN-2":{"id":"BTN-2","clean":"defaultcleanBTN-2","dest":"defaultdestBTN-2","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://in.finance.yahoo.com/quote/SBIN.BO"}},"BTN-3":{"id":"BTN-3","clean":"defaultcleanBTN-3","dest":"defaultdestBTN-3","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://in.finance.yahoo.com/quote/SBIN.BO"}},"BTN-5":{"id":"BTN-5","clean":"defaultcleanBTN-5","dest":"defaultdestBTN-5","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://in.finance.yahoo.com/quote/SBIN.BO"}},"BTN-6":{"id":"BTN-6","clean":"defaultcleanBTN-6","dest":"defaultdestBTN-6","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://in.finance.yahoo.com/quote/SBIN.BO"}},"BTN-7":{"id":"BTN-7","clean":"defaultcleanBTN-7","dest":"defaultdestBTN-7","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://in.finance.yahoo.com/quote/SBIN.BO"}},"BTN-8":{"id":"BTN-8","clean":"defaultcleanBTN-8","dest":"defaultdestBTN-8","metaSize":true,"w":120,"h":60,"enable":true,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://in.finance.yahoo.com/quote/SBIN.BO"}},"BTNA":{"id":"BTNA","clean":"defaultcleanBTNA","dest":"defaultdestBTNA","metaSize":true,"w":120,"h":60,"enable":true,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://in.finance.yahoo.com/quote/SBIN.BO"}},"BTNB":{"id":"BTNB","clean":"defaultcleanBTNB","dest":"defaultdestBTNB","metaSize":true,"w":120,"h":60,"enable":true,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://in.finance.yahoo.com/quote/SBIN.BO"}},"BTNC":{"id":"BTNC","clean":"defaultcleanBTNC","dest":"defaultdestBTNC","metaSize":true,"w":120,"h":60,"enable":true,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://in.finance.yahoo.com/quote/SBIN.BO"}},"BTND":{"id":"BTND","clean":"defaultcleanBTND","dest":"defaultdestBTND","metaSize":true,"w":120,"h":60,"enable":true,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://in.finance.yahoo.com/quote/SBIN.BO"}},"WIDGET":{"id":"WIDGET","clean":"defaultcleanWIDGET","dest":"defaultdestWIDGET","metaSize":false,"w":650,"h":635,"enable":true,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://in.finance.yahoo.com/quote/SBIN.BO"}},"W ...
# window.DARLA_CONFIG.servicePath = window.location.protocol + "//fc.yahoo.com/sdarla/php/fc.php";window.DARLA_CONFIG.dm = 1;window.DARLA_CONFIG.onStartRequest = function() {window._perfMark('DARLA_REQSTART');};
# window.DARLA_CONFIG.onFinishRequest = function() {window._perfMark('DARLA_REQEND');};
# window.DARLA_CONFIG.onStartParse = function() {window._perfMark('DARLA_PSTART');};
# window.DARLA_CONFIG.onSuccess = function(eventName) {if (eventName === 'AUTO') {return;}if (window._DarlaEvents) {window._DarlaEvents.emit("success", {eventName: eventName});}window._perfMark('DARLA_DONE_' + eventName);window._darlaSuccessEvt = eventName;if (window._loadEvt) {window._fireAdPerfBeacon(eventName);}};
# window.DARLA_CONFIG.onStartPosRender = function(posItem) {var posId = posItem && posItem.pos;window._perfMark('DARLA_ADSTART_' + posId);if (window._pushAdPerfMetric) {window._pushAdPerfMetric("DARLA_ADSTART_" + posId);}};
# window.DARLA_CONFIG.onFinishPosRender = function(posId, reqList, posItem) {var ltime;window._perfMark('DARLA_ADEND_' + posId);window._perfMeasure('DARLA_RENDERTIME_' + posId, 'DARLA_ADSTART_'+posId, 'DARLA_ADEND_'+posId);if(window._DarlaEvents) {window._DarlaEvents.emit("finishrender", {pos:posId, list:reqList, item:posItem});}var aboveFoldPositions = ["WPS","MAST","LDRB","SPRZ","SPL","LREC","BTN","BTN-1","BTN-2","BTN-3","BTN1","BTNA","BTNB","BTNC","BTND","FB2","FB2-1","FB2-2","FB2-3","FB2A","FB2B","FB2C","FB2D","NE4","NE4-1","NE4-2","NE4-3","NE4A","NE4B","NE4C","NE4D"];if (window._pushAdPerfMetric) {if (window.performance && window.performance.now) {ltime = window.performance.now();}window._pushAdPerfMetric("ADEND_"+posId);var adModDiv = posItem.conf.dest.replace("dest", "") + "-sizer";setTimeout(function () {if (window.performance && window.YAFT !== undefined &&window.YAFT.isInitialized() && -1 !== aboveFoldPositions.indexOf(posId)) {window.YAFT.triggerCustomTiming(adModDiv, "", ltime);}}, 300);}};
# window.DARLA_CONFIG.onBeforePosMsg = function(msg, posId) {var maxWidth = 970, maxHeight = 600;var newWidth, newHeight, pos;if ("MAST" !== posId) {return;}if (msg === "resize-to") {newWidth = arguments[2];newHeight = arguments[3];} else if (msg === "exp-push" || msg === "exp-ovr") {pos = $sf.host.get("MAST");newWidth = pos.conf.w + arguments[6] + arguments[7];newHeight = pos.conf.h + arguments[5] + arguments[8];}if (newWidth > maxWidth || newHeight > maxHeight) {return true;}};
# window.DARLA_CONFIG.onFinishParse = function(eventName, response) {try {window._perfMark('DARLA_PEND');if (eventName === "prefetch") {window._DarlaPrefetchResponse = response;}if (window._DarlaEvents) {window._DarlaEvents.emit("finishparse", {response: response,eventName: eventName});}} catch (e) {console.error(e);throw e;}
# };
# window.DARLA_CONFIG.onStartPrefetchRequest = function(eventName) {window._perfMark('DARLA_PFSTART');};
# window.DARLA_CONFIG.onFinishPrefetchRequest = function(eventName, status) {window._perfMark('DARLA_PFEND');try {window._DarlaEvents.emit('finishprefetch', {status: status,eventName: eventName});} catch (e) {console.error(e);throw e;}
# };
# window.DARLA_CONFIG.onPosMsg = function(cmd, pos, msg) {try {if (window._DarlaEvents && cmd === "cmsg") {var posmsg = {pos: pos,msg: msg};window._DarlaEvents.emit("splashmsg", posmsg);if (window._adPosMsg) {window._adPosMsg[window._adPosMsg.length] = posmsg;}}if (window._DarlaEvents && (cmd === "ui-fclose-show" || cmd === "ui-fclose-close")) {setTimeout(function _emitAdResize(){window._DarlaEvents.emit("adresize", {pos: pos})}, 0);}} catch (e) {console.error(e);throw e;}
# };
# (function () {var _onloadEvt = function _onloadEvtHandler() {window._loadEvt = true;if (window._darlaSuccessEvt) {window._fireAdPerfBeacon(window._darlaSuccessEvt);}};if (window.addEventListener) {window.addEventListener("load", _onloadEvt);} else if (window.attachEvent) {window.attachEvent("onload", _onloadEvt);}function _onDarlaError (type) {return function _darlaErrHandler(evName) {try {if (window._DarlaEvents) {window._DarlaEvents.emit("darlaerror" + evName);window._DarlaEvents.emit("darlaerror", {type: type,eventName: evName,error: true});}} catch (e) {console.error(e);throw e;}};};window.DARLA_CONFIG.onRequestTimeout = _onDarlaError("requestTimeout");window.DARLA_CONFIG.onRenderTimeout = _onDarlaError("renderTimeout");window.DARLA_CONFIG.onFailure = _onDarlaError("failure");window.DARLA_CONFIG.onIdle = function onDarlaIdle () {    try {        window._DarlaEvents && window._DarlaEvents.emit("onIdle");    } catch (e) {        console.error(e);        throw e;    }};})();
# window.$sf = window.sf = {};
# window.$sf.host = {onReady: function (autorender, deferrender, firstRenderPos, deferRenderDelay) {window._perfMark('DARLA_ONREADY');window._perfMeasure('DARLA_ONREADY');window.sfready = true;if (window._DarlaEvents && !autorender) {window._DarlaEvents.emit("darlaboot");} else if (autorender){window._perfMark('DARLA_RSTART');if (typeof DARLA !== "undefined" && DARLA) {if (deferrender && firstRenderPos) {var firstBatchPos = [];var prefetchedPos = DARLA.prefetched();if (prefetchedPos.length <= 0) {return;}var firstRender = firstRenderPos.split(',');if (firstRender && firstRender.length > 0) {for (var i = 0; i < firstRender.length; i++) {var position = firstRender[i];var index = prefetchedPos.indexOf(position);if (index >= 0) {firstBatchPos = firstBatchPos.concat(prefetchedPos.splice(index, 1));}};}if (firstBatchPos.length > 0) {var renderWithRetry = function(pos) {if (DARLA.inProgress()) {var waittime = 600, maxwait = 100, deferRetry = 0, interval;interval = setInterval(function() {deferRetry ++;if (!DARLA.inProgress()){clearInterval(interval);DARLA.render(pos);}if (deferRetry > maxwait){clearInterval(interval);}}, waittime);} else {DARLA.render(pos);}};renderWithRetry(firstBatchPos);setTimeout(renderWithRetry, deferRenderDelay, prefetchedPos);} else {DARLA.render();}} else {DARLA.render();}}}}
# };
# window.sf_host = window.$sf.host;
# document.onreadystatechange = function () {if (document.readyState == "interactive") {window._perfMark('DOM_INTERACTIVE');}};</script>
# <script _ver="3-21-0" id="fc" type="text/x-safeframe">{"positions":[{"id":"FOOT","html":"<!-- SpaceID=0 robot -->\n","lowHTML":"","meta":{"y":{"pos":"FOOT","cscHTML":false,"cscURI":"","behavior":"non_exp","adID":"#19","matchID":"#19","bookID":false,"slotID":false,"serveType":false,"ttl":-1,"err":"robot","hasExternal":false,"supp_ugc":false,"placementID":-1,"fdb":null,"serveTime":-1,"impID":"","creativeID":-1,"adc":"{\"label\":\"AdChoices\",\"url\":\"https:\\\/\\\/info.yahoo.com\\\/privacy\\\/in\\\/yahoo\\\/relevantads.html\",\"close\":\"Close\",\"closeAd\":\"Close ad\",\"showAd\":\"Show ad\",\"collapse\":\"Collapse\",\"fdb\":\"I don't like this ad\",\"code\":\"en-in\"}","is3rd":1,"facStatus":{},"userProvidedData":{},"facRotation":{},"slotData":{}}}},{"id":"FSRVY","html":"<!-- SpaceID=0 robot -->\n","lowHTML":"","meta":{"y":{"pos":"FSRVY","cscHTML":false,"cscURI":"","behavior":"non_exp","adID":"#19","matchID":"#19","bookID":false,"slotID":false,"serveType":false,"ttl":-1,"err":"robot","hasExternal":false,"supp_ugc":false,"placementID":-1,"fdb":null,"serveTime":-1,"impID":"","creativeID":-1,"adc":"{\"label\":\"AdChoices\",\"url\":\"https:\\\/\\\/info.yahoo.com\\\/privacy\\\/in\\\/yahoo\\\/relevantads.html\",\"close\":\"Close\",\"closeAd\":\"Close ad\",\"showAd\":\"Show ad\",\"collapse\":\"Collapse\",\"fdb\":\"I don't like this ad\",\"code\":\"en-in\"}","is3rd":1,"facStatus":{},"userProvidedData":{},"facRotation":{},"slotData":{}}}}],"conf":{"useYAC":0,"usePE":1,"servicePath":"","xservicePath":"","beaconPath":"","renderPath":"","allowFiF":false,"srenderPath":"https:\/\/s.yimg.com\/rq\/darla\/3-21-0\/html\/r-sf.html","renderFile":"https:\/\/s.yimg.com\/rq\/darla\/3-21-0\/html\/r-sf.html","sfbrenderPath":"https:\/\/s.yimg.com\/rq\/darla\/3-21-0\/html\/r-sf.html","msgPath":"https:\/\/fc.yahoo.com\/unsupported-1946.html","cscPath":"https:\/\/s.yimg.com\/rq\/darla\/3-21-0\/html\/r-csc.html","root":"sdarla","edgeRoot":"https:\/\/s.yimg.com\/rq\/darla\/3-21-0","sedgeRoot":"https:\/\/s.yimg.com\/rq\/darla\/3-21-0","version":"3-21-0","tpbURI":"","hostFile":"https:\/\/s.yimg.com\/rq\/darla\/3-21-0\/js\/g-r-min.js","property":"finance_en-IN","fdb_locale":"What don't you like about this ad?|It's offensive|Something else|Thank you for helping us improve your Yahoo experience|It's not relevant|It's distracting|I don't like this ad|Send|Done|Why do I see ads?|Learn more about your feedback.|Want an ad-free inbox? Upgrade to Yahoo Mail Pro!|Upgrade now","positions":{"FOOT":{"dest":"destFOOT","id":"FOOT"},"FSRVY":{"dest":"destFSRVY","id":"FSRVY"}},"events":{"DEFAULT":{"ult":{"pg":{"property":"finance_en-IN","test":"finance-IN-en-IN-def"}},"clw":{"LREC":{"blocked_by":"MON-1"},"MON-1":{"blocked_by":"LREC"},"MAST":{"blocked_by":"SPL,LDRB"},"LDRB":{"blocked_by":"MAST,SPL"},"SPL":{"blocked_by":"MAST,LDRB"}}}},"lang":"en-IN","spaceID":"985404724","debug":false,"asString":"{\"useYAC\":0,\"usePE\":1,\"servicePath\":\"\",\"xservicePath\":\"\",\"beaconPath\":\"\",\"renderPath\":\"\",\"allowFiF\":false,\"srenderPath\":\"https:\\\/\\\/s.yimg.com\\\/rq\\\/darla\\\/3-21-0\\\/html\\\/r-sf.html\",\"renderFile\":\"https:\\\/\\\/s.yimg.com\\\/rq\\\/darla\\\/3-21-0\\\/html\\\/r-sf.html\",\"sfbrenderPath\":\"https:\\\/\\\/s.yimg.com\\\/rq\\\/darla\\\/3-21-0\\\/html\\\/r-sf.html\",\"msgPath\":\"https:\\\/\\\/fc.yahoo.com\\\/unsupported-1946.html\",\"cscPath\":\"https:\\\/\\\/s.yimg.com\\\/rq\\\/darla\\\/3-21-0\\\/html\\\/r-csc.html\",\"root\":\"sdarla\",\"edgeRoot\":\"https:\\\/\\\/s.yimg.com\\\/rq\\\/darla\\\/3-21-0\",\"sedgeRoot\":\"https:\\\/\\\/s.yimg.com\\\/rq\\\/darla\\\/3-21-0\",\"version\":\"3-21-0\",\"tpbURI\":\"\",\"hostFile\":\"https:\\\/\\\/s.yimg.com\\\/rq\\\/darla\\\/3-21-0\\\/js\\\/g-r-min.js\",\"property\":\"finance_en-IN\",\"fdb_locale\":\"What don't you like about this ad?|It's offensive|Something else|Thank you for helping us improve your Yahoo experience|It's not relevant|It's distracting|I don't like this ad|Send|Done|Why do I see ads?|Learn more ...
# <!-- sg3-sdarlaws-004.adx.sg3.yahoo.com Sun Dec 15 11:24:20 UTC 2019 -->
# <script type="text/javascript">if (typeof DARLA !== "undefined" && DARLA) {DARLA.config(window.DARLA_CONFIG);window.sf_host.onReady(true,true,'LDRB,LREC,MON',3000);}</script>
# <style>
# .hide-lrec-ad .darla-lrec-ad {display: none;}.hide-non-lrec34 .darla-nonlrec34-ad {display: none;}.hide-non-lrec34 .sticky-outer-wrapper .tdv2-applet-stream .js-stream-content .controller,.hide-non-lrec34 .YDC-Height-Container .tdv2-applet-stream .js-stream-content .controller {display: none;}.hide-non-lrec34ldrb .darla-nonlrec34ldrb-ad {display: none;}.hide-non-lrec34ldrb .sticky-outer-wrapper .tdv2-applet-stream .js-stream-content .controller,.hide-non-lrec34ldrb .YDC-Height-Container .tdv2-applet-stream .js-stream-content .controller {display: none;}.hide-lrec-groups-lrec12 .darla-nonlrec34ldrb-ad,.hide-lrec-groups-lrec34 .darla-lrec34-ad,.hide-all-lrecs .darla-lrec-ad {display: none;}</style>
# </div><script>
# (function (root) {
# /* -- Data -- */
# root.App || (root.App = {});
# root.App.now = 1576409060016;
# root.App.main = {"context":{"dispatcher":{"stores":{"PageStore":{"currentPageName":"quote","currentRenderTargetId":"default","pagesConfigRaw":{"base":{"quote":{"layout":{"bundleName":"yahoodotcom-layout.MobileOneColumnLayout","name":"MobileOneColumnLayout","config":{"enableHeaderCollapse":false,"additionalBodyWrapperClasses":"Bgc($layoutBgColor)!","contentWrapperClasses":"Bgc($layoutBgColor)!","Header":{"isFixed":true,"uhContainerClasses":"Bgi($uhGrayGradient) D(n)--print","navContainerClasses":"Bgi($navrailGrayGradient) Bxsh($navrailShadow) Pos(r) hasScrolled_Bxsh(headerShadow) Panel-open_Bxsh(headerShadow)","navTransitionClasses":"HideNavrail_Translate3d(0,-46px,0) Panel-open_Translate3d(0,-46px,0)","secondaryNavContainerClasses":"hasScrolled_Bdbw(0px) Bgc(white) Bxsh($navrailShadow) D(n)--print","height":115},"fetchNewAttribution":true,"hideFeatureBar":true,"Side":null,"UH":{"containerClasses":"lw-nav-open_D(n)","height":54,"slotHeight":54}},"meta":{"property":{"twitter:site":"@YahooFinance"},"name":{"viewport":"width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no"}}},"meta":{"property":{"twitter:site":"@YahooIndia","fb:pages":"131747896861126","og:image":"https:\u002F\u002Fs.yimg.com\u002Fcv\u002Fapiv2\u002Fsocial\u002Fimages\u002Fyahoo_default_logo.png"}},"regions":{"SecondaryNav":[],"Overlay":[{"bundleName":"tdv2-applet-navrail","name":"DesktopNav","perfLabel":"NavLite","config":{"ui":{"navCache":true,"remoteAdapter":true,"makeSticky":false,"isNavLink":true,"relativeLinks":true,"darkTheme":true,"offsetHack":"Bgc(t)!","selectColor":"C($finNavBlueText)! Bdbw(0px) H(42px) Trstf(l) Trsde(0s) Trsdu(.18s) Trsp(border-bottom-width)","subnavClasses":"Bgc(white)!","hoverColor":"C($finNavBlueText):h","overrideColor":"C($finNavBlueText)","propertyHomeSelectColor":"Bdbc($c-fuji-blue-1-a) Bdbs(s)! Bdbw(4px) H(38px)","propertyHomeClasses":"Tt(c)! Bdbc($c-fuji-blue-1-a):h Bdbs(s):h Bdbw(4px):h H(38px) Trstf(l) Trsde(0s) Trsdu(.18s) Trsp(border-bottom-width)","navLinkClasses":"Tt(n)!","navLinkClassesOnHover":"Bdbc($c-fuji-blue-1-a)!:h Bdbs(s)!:h Bdbw(4px)!:h H(38px) Trstf(l) Trsde(0s) Trsdu(.18s) Trsp(border-bottom-width)","navLinkNonHoverClasses":"C($topNavLinkGray) Bdbs(n)","highlightTriangleColor":"transparent transparent #fff"},"featureSwitches":{"useNavSelectLogic":true},"i13n":{"itc":0,"sec":"navrail"},"site":"finance","theme":{"mobileIcon":"LogoYahoo2019","mobileIconHeight":60,"mobileIconWidth":100}},"props":{"key":"Overlay-0-DesktopNav","id":"Overlay-0-DesktopNav"},"isPageComposite":true},{"bundleName":"react-lightbox","name":"Lightbox","props":{"key":"Overlay-1-Lightbox","id":"Overlay-1-Lightbox"},"isPageComposite":true},{"bundleName":"react-finance","name":"Null","props":{"key":"Overlay-2-Null","id":"Overlay-2-Null"},"isPageComposite":true}],"Lead":[],"Col1":[{"bundleName":"tdv2-applet-swisschamp","name":"Empty","props":{"key":"Col1-0-Empty","id":"Col1-0-Empty"},"isPageComposite":true},{"bundleName":"QuotePage","name":"QuoteNav","props":{"className":"Pos(r) Mstart(a) Mend(a) Bxsh($horzScrollMenuShadow)","type":"scroll","key":"Col1-1-QuoteNav","id":"Col1-1-QuoteNav"},"isPageComposite":true},{"bundleName":"QuotePage","name":"QuoteHeader","props":{"type":"narrow","key":"Col1-2-QuoteHeader","id":"Col1-2-QuoteHeader"},"isPageComposite":true},{"bundleName":"QuotePage.summary","name":"QuoteSummary","props":{"enableTrading":false,"enableQuotePencilAd":false,"followFullChartLink":true,"key":"Col1-3-QuoteSummary","id":"Col1-3-QuoteSummary"},"isPageComposite":true},{"bundleName":"Quote.summary","name":"Summary","props":{"key":"Col1-4-Summary","id":"Col1-4-Summary"},"isPageComposite":true},{"bundleName":"tdv2-applet-stream","name":"Stream","perfLabel":"FinStream","config":{"ui":{"enable_lead_fallback_image":true,"image_quality_override":true,"pubtime_maxage":0,"follow_content":false,"inline_filters_max":0,"relative_links":true,"stream_navparam_count":2,"storyline_navparam_enabled":false,"storyline_enabled":true,"storylin ...
# }(this));
# </script><script defer="" src="https://s.yimg.com/zz/combo?uc/finance/dd-site/js/main-lightweight.fe55e51c018912cf5287.lightweight.js&amp;os/yaft/yaft-0.3.27.min.js&amp;os/yaft/yaft-plugin-aftnoad-0.1.5.min.js"></script>
# <script>window.webpackPublicPath='https://s.yimg.com/uc/finance/dd-site/js/';</script></body></html>

# %%
soup.findAll("a") #extract all tags "a"
# Out:
# [<a class="Bgpx(0) Bgr(nr) Cur(p) D(b) H(35px) Bgz(702px) Mx(a)! W(92px)" data-reactid="12" href="https://in.finance.yahoo.com/" id="uh-logo"><b class="Hidden" data-reactid="13">Yahoo</b></a>,
#  <a class="Pos(r) D(ib) Ta(s) Td(n):h" data-reactid="45" href="https://mail.yahoo.com/?.intl=in&amp;.lang=en-IN&amp;.partner=none&amp;.src=finance" id="uh-mail"><svg class="Cur(p)" data-icon="NavMail" data-reactid="46" height="35" style="fill:#400090;stroke:#400090;stroke-width:0;vertical-align:bottom;" viewbox="0 0 512 512" width="30"><path d="M460.586 91.31H51.504c-10.738 0-19.46 8.72-19.46 19.477v40.088l224 104.03 224-104.03v-40.088c0-10.757-8.702-19.478-19.458-19.478M32.046 193.426V402.96c0 10.758 8.72 19.48 19.458 19.48h409.082c10.756 0 19.46-8.722 19.46-19.48V193.428l-224 102.327-224-102.327z" data-reactid="47"></path></svg><b class="Lh(userNavTextLh) D(ib) C($c-fuji-purple-1-c) Fz(14px) Fw(b) Va(t) Mstart(6px)" data-reactid="48">Mail</b></a>,
#  <a class="Lh(50px) Ta(c) Bdbw(3px) Bdbs(s) Px(12px) C($linkColor) Bdbc($seperatorColor) D(b) Td(n) selected_Bdbc($linkColor) selected_C(black) selected_Bgc($navSelectedBlue)" data-reactid="7" href="/quote/SBIN.BO?p=SBIN.BO"><!-- react-text: 8 --><!-- /react-text --><span data-reactid="9">Summary</span></a>,
#  <a class="Lh(50px) Ta(c) Bdbw(3px) Bdbs(s) Px(12px) C($linkColor) Bdbc($seperatorColor) D(b) Td(n) selected_Bdbc($linkColor) selected_C(black) selected_Bgc($navSelectedBlue)" data-reactid="11" href="/quote/SBIN.BO/key-statistics?p=SBIN.BO"><!-- react-text: 12 --><!-- /react-text --><span data-reactid="13">Statistics</span></a>,
#  <a class="Lh(50px) Ta(c) Bdbw(3px) Bdbs(s) Px(12px) C($linkColor) Bdbc($seperatorColor) D(b) Td(n) selected_Bdbc($linkColor) selected_C(black) selected_Bgc($navSelectedBlue)" data-reactid="15" href="/quote/SBIN.BO/history?p=SBIN.BO"><!-- react-text: 16 --><!-- /react-text --><span data-reactid="17">Historical data</span></a>,
#  <a class="Lh(50px) Ta(c) Bdbw(3px) Bdbs(s) Px(12px) C($linkColor) Bdbc($seperatorColor) D(b) Td(n) selected_Bdbc($linkColor) selected_C(black) selected_Bgc($navSelectedBlue)" data-reactid="19" href="/quote/SBIN.BO/profile?p=SBIN.BO"><!-- react-text: 20 --><!-- /react-text --><span data-reactid="21">Profile</span></a>,
#  <a class="Lh(50px) Ta(c) Bdbw(3px) Bdbs(s) Px(12px) C($linkColor) Bdbc($seperatorColor) D(b) Td(n) selected_Bdbc($linkColor) selected_C(black) selected_Bgc($navSelectedBlue)" data-reactid="23" href="/quote/SBIN.BO/financials?p=SBIN.BO"><!-- react-text: 24 --><!-- /react-text --><span data-reactid="25">Financials</span><img alt="new" class="H(13px) W(25px) Mstart(5px) Va(m)" data-reactid="26" src="https://s.yimg.com/uc/New.png"/></a>,
#  <a class="Lh(50px) Ta(c) Bdbw(3px) Bdbs(s) Px(12px) C($linkColor) Bdbc($seperatorColor) D(b) Td(n) selected_Bdbc($linkColor) selected_C(black) selected_Bgc($navSelectedBlue)" data-reactid="28" href="/quote/SBIN.BO/analysis?p=SBIN.BO"><!-- react-text: 29 --><!-- /react-text --><span data-reactid="30">Analysis</span></a>,
#  <a class="Lh(50px) Ta(c) Bdbw(3px) Bdbs(s) Px(12px) C($linkColor) Bdbc($seperatorColor) D(b) Td(n) selected_Bdbc($linkColor) selected_C(black) selected_Bgc($navSelectedBlue)" data-reactid="32" href="/quote/SBIN.BO/options?p=SBIN.BO"><!-- react-text: 33 --><!-- /react-text --><span data-reactid="34">Options</span></a>,
#  <a class="Lh(50px) Ta(c) Bdbw(3px) Bdbs(s) Px(12px) C($linkColor) Bdbc($seperatorColor) D(b) Td(n) selected_Bdbc($linkColor) selected_C(black) selected_Bgc($navSelectedBlue)" data-reactid="36" href="/quote/SBIN.BO/holders?p=SBIN.BO"><!-- react-text: 37 --><!-- /react-text --><span data-reactid="38">Holders</span></a>,
#  <a class="Lh(50px) Ta(c) Bdbw(3px) Bdbs(s) Px(12px) C($linkColor) Bdbc($seperatorColor) D(b) Td(n) selected_Bdbc($linkColor) selected_C(black) selected_Bgc($navSelectedBlue)" data-reactid="40" href="/quote/SBIN.BO/sustainability?p=SBIN.BO"><!-- react-text: 41 --><!-- /react-text --><span data-reactid="42">Sustainability</span></a>,
#  <a class="Mend(10px) P(0px) M(0px) C($linkColor) C($primaryColor):h Bd(0px) O(n)" data-reactid="7" href="/quote/SBIN.BO/news?p=SBIN.BO"><div class="Fw(500) D(ib) Pend(10px) H(18px) BdEnd Bdc($seperatorColor)" data-reactid="8"><span data-reactid="9">News</span></div></a>,
#  <a class="Mend(10px) P(0px) M(0px) C($linkColor) C($primaryColor):h Bd(0px) O(n)" data-reactid="10" href="/quote/SBIN.BO/press-releases?p=SBIN.BO"><div class="Fw(500) D(ib) Pend(10px) H(18px)" data-reactid="11"><span data-reactid="12">Press Releases</span></div></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="13" href="/news/sbis-credit-card-business-plans-164715145.html"><u class="StretchedBox" data-reactid="14"></u><!-- react-text: 15 -->Carlyle Group set to make bumper profit from SBI Cards IPO<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="26" href="/news/indian-police-register-42-bank-163142648.html"><u class="StretchedBox" data-reactid="27"></u><!-- react-text: 28 -->Indian police register 42 new bank fraud cases<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="39" href="/news/indian-shares-rise-special-muhurat-154020430.html"><u class="StretchedBox" data-reactid="40"></u><!-- react-text: 41 -->Indian shares rise in special 'muhurat' session on Diwali<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="52" href="/news/state-bank-india-profit-triples-091717253.html"><u class="StretchedBox" data-reactid="53"></u><!-- react-text: 54 -->SBI profit beats on higher interest income, better asset quality<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="65" href="/news/sbis-credit-card-business-aims-113627485.html"><u class="StretchedBox" data-reactid="66"></u><!-- react-text: 67 -->SBI's credit card business aims to raise $1.1 billion via IPO: source<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="78" href="/news/state-bank-india-cuts-benchmark-082101757.html"><u class="StretchedBox" data-reactid="79"></u><!-- react-text: 80 -->State Bank of India cuts benchmark lending rates by 15 bps<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="88" href="/news/state-bank-india-seeks-bids-071022814.html"><u class="StretchedBox" data-reactid="89"></u><!-- react-text: 90 -->State Bank of India seeks bids for Videocon's overseas oil, gas assets<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="101" href="/news/sbi-posts-profit-first-quarter-083245260.html"><u class="StretchedBox" data-reactid="102"></u><!-- react-text: 103 -->State Bank of India warns of muted credit growth, misses quarterly profit estimates<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="114" href="/news/exclusive-sbi-tightens-lending-terms-175533859.html"><u class="StretchedBox" data-reactid="115"></u><!-- react-text: 116 -->Exclusive: SBI tightens lending terms for auto dealers - source, internal memo<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="127" href="/news/exclusive-indias-sbi-tightens-lending-175450256.html"><u class="StretchedBox" data-reactid="128"></u><!-- react-text: 129 -->Exclusive: India's SBI tightens lending terms for auto dealers - source, internal memo<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="140" href="/news/sbi-cuts-deposit-rates-keeps-104228583.html"><u class="StretchedBox" data-reactid="141"></u><!-- react-text: 142 -->SBI cuts deposit rates, keeps lending rates unchanged<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="153" href="/news/jet-airways-lenders-approve-interim-142019586.html"><u class="StretchedBox" data-reactid="154"></u><!-- react-text: 155 -->Jet Airways' lenders approve interim finance plan for the carrier<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="166" href="/news/lenders-bankrupt-jet-airways-attempt-025917265.html"><u class="StretchedBox" data-reactid="167"></u><!-- react-text: 168 -->Lenders of bankrupt Jet Airways to attempt to sell carrier again<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="179" href="/news/wilful-defaults-india-cross-21-131914303.html"><u class="StretchedBox" data-reactid="180"></u><!-- react-text: 181 -->Wilful defaults in India cross $21 billion in 2018-19<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="192" href="/news/nclt-admits-insolvency-plea-against-134437326.html"><u class="StretchedBox" data-reactid="193"></u><!-- react-text: 194 -->NCLT admits insolvency plea against Jet Airways<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="205" href="/news/nifty-sensex-edge-lower-over-050958387.html"><u class="StretchedBox" data-reactid="206"></u><!-- react-text: 207 -->Nifty, Sensex end weaker amid global slowdown worries<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="218" href="/news/jet-airways-slumps-reports-etihads-044735809.html"><u class="StretchedBox" data-reactid="219"></u><!-- react-text: 220 -->Jet Airways slumps after reports of Etihad's non-binding offer<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="231" href="/news/state-bank-india-says-two-095227463.html"><u class="StretchedBox" data-reactid="232"></u><!-- react-text: 233 -->Etihad submits bid for Jet Airways, eyes minority stake<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="244" href="/news/state-bank-india-gets-sealed-142812373.html"><u class="StretchedBox" data-reactid="245"></u><!-- react-text: 246 -->State Bank of India gets sealed bid for Jet Airways from Etihad<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="254" href="/news/state-bank-india-turns-profit-083353157.html"><u class="StretchedBox" data-reactid="255"></u><!-- react-text: 256 -->SBI misses fourth-quarter profit estimate, provisions up quarter-on-quarter<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="264" href="/m/730e15e2-c699-3918-b5a0-169ab2239590/ss_don%26%2339%3Bt-blame-state-banks.html" target="_self"><u class="StretchedBox" data-reactid="265"></u><!-- react-text: 266 -->Don't blame state banks for weakness in India's economy, says the country's largest lender<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="277" href="/m/cec40fb6-0b5b-3b15-b2ce-71581ece6c6a/ss_jet-airways%26%2339%3B-lenders-hope.html" target="_self"><u class="StretchedBox" data-reactid="278"></u><!-- react-text: 279 -->Jet Airways' lenders hope bidding process can save airline<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="287" href="/news/timeline-jet-airways-joy-flying-151825293.html"><u class="StretchedBox" data-reactid="288"></u><!-- react-text: 289 -->Timeline: Jet Airways - How the 'Joy of Flying' airline's dreams soured<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="297" href="/m/77145535-3235-3f26-98b6-13fc79fd9922/ss_jet-airways-stock-suffers.html" target="_self"><u class="StretchedBox" data-reactid="298"></u><!-- react-text: 299 -->Jet Airways stock suffers heavy losses after emergency funding doubts<!-- /react-text --></a>,
#  <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="307" href="/m/8ed0cc96-18ee-3b60-9d01-ede17fc37b07/ss_india%26%2339%3Bs-jet-airways.html" target="_self"><u class="StretchedBox" data-reactid="308"></u><!-- react-text: 309 -->India's Jet Airways cancels all international flights as debt problems deepen<!-- /react-text --></a>,
#  <a class="nr-applet-nav-item Td(n) rapidnofollow Ell Td(n) D(ib) Lh(itemHeight_uhMagDesign) Tt(c)! Bdbc($c-fuji-blue-1-a):h Bdbs(s):h Bdbw(4px):h H(38px) Trstf(l) Trsde(0s) Trsdu(.18s) Trsp(border-bottom-width) C(darkTheme)" data-reactid="9" href="/" title="Finance"><!-- react-text: 10 -->Finance<!-- /react-text --></a>,
#  <a class="nr-applet-nav-item Td(n) rapidnofollow nr-list-link Ell Td(n) D(ib) Bdbs(s):h Pos(r) Bdc($fg-header) Lh(cateNavHeight) C(hoverColor):h Tt(n)! C($fg-header) Mt(cateNavMargin) C(darkTheme) Bdc(darkTheme) Tt(c) Fz(14px) openSubNav" data-reactid="17" href="/watchlists" role="listitem link" title="Watchlists"><!-- react-text: 18 -->Watchlists<!-- /react-text --></a>,
#  <a class="nr-applet-nav-item Td(n) rapidnofollow nr-list-link Ell Td(n) D(ib) Bdbs(s):h Pos(r) Bdc($fg-header) Lh(cateNavHeight) C(hoverColor):h Tt(n)! C($fg-header) Mt(cateNavMargin) C(darkTheme) Bdc(darkTheme) Tt(c) Fz(14px) openSubNav" data-reactid="20" href="/budget" role="listitem link" title="Budget 2019"><!-- react-text: 21 -->Budget 2019<!-- /react-text --></a>,
#  <a class="nr-applet-nav-item Td(n) rapidnofollow nr-list-link Ell Td(n) D(ib) Bdbs(s):h Pos(r) Bdc($fg-header) Lh(cateNavHeight) C(hoverColor):h Tt(n)! C($fg-header) Mt(cateNavMargin) C(darkTheme) Bdc(darkTheme) Tt(c) Fz(14px) openSubNav" data-reactid="23" href="/portfolios" role="listitem link" title="My Portfolio"><!-- react-text: 24 -->My Portfolio<!-- /react-text --></a>,
#  <a class="nr-applet-nav-item Td(n) rapidnofollow nr-list-link Ell Td(n) D(ib) Bdbs(s):h Pos(r) Bdc($fg-header) Lh(cateNavHeight) C(hoverColor):h Tt(n)! C($fg-header) Mt(cateNavMargin) C(darkTheme) Bdc(darkTheme) Tt(c) Fz(14px) openSubNav" data-reactid="26" href="/personal-finance" role="listitem link" title="Personal Finance"><!-- react-text: 27 -->Personal Finance<!-- /react-text --></a>,
#  <a class="nr-applet-nav-item Td(n) rapidnofollow nr-list-link Ell Td(n) D(ib) Bdbs(s):h Pos(r) Bdc($fg-header) Lh(cateNavHeight) C(hoverColor):h Tt(n)! C($fg-header) Mt(cateNavMargin) C(darkTheme) Bdc(darkTheme) Tt(c) Fz(14px) openSubNav" data-reactid="29" href="/topic/tech" role="listitem link" title="Technology"><!-- react-text: 30 -->Technology<!-- /react-text --></a>,
#  <a class="nr-applet-nav-item Td(n) rapidnofollow nr-list-link Ell Td(n) D(ib) Bdbs(s):h Pos(r) Bdc($fg-header) Lh(cateNavHeight) C(hoverColor):h Tt(n)! C($fg-header) Mt(cateNavMargin) C(darkTheme) Bdc(darkTheme) Tt(c) Fz(14px) openSubNav" data-reactid="32" href="/topic/autos" role="listitem link" title="Autos"><!-- react-text: 33 -->Autos<!-- /react-text --></a>,
#  <a class="nr-applet-nav-item Td(n) rapidnofollow nr-list-link Ell Td(n) D(ib) Bdbs(s):h Pos(r) Bdc($fg-header) Lh(cateNavHeight) C(hoverColor):h Tt(n)! C($fg-header) Mt(cateNavMargin) C(darkTheme) Bdc(darkTheme) Tt(c) Fz(14px) openSubNav" data-reactid="38" href="/topic/latestnews" role="listitem link" title="News"><!-- react-text: 39 -->News<!-- /react-text --></a>,
#  <a class="nr-applet-nav-item Td(n) rapidnofollow nr-list-link Ell Td(n) D(ib) Bdbs(s):h Pos(r) Bdc($fg-header) Lh(cateNavHeight) C(hoverColor):h Tt(n)! C($fg-header) Mt(cateNavMargin) C(darkTheme) Bdc(darkTheme) Tt(c) Fz(14px) openSubNav" data-reactid="41" href="/topic/videos" role="listitem link" title="Videos"><!-- react-text: 42 -->Videos<!-- /react-text --></a>]

# %%
all_links=soup.findAll("a")
for elem in all_links:
    link=str(elem.get('href'))
    print(link)
# Out:
# https://in.finance.yahoo.com/
# https://mail.yahoo.com/?.intl=in&.lang=en-IN&.partner=none&.src=finance
# /quote/SBIN.BO?p=SBIN.BO
# /quote/SBIN.BO/key-statistics?p=SBIN.BO
# /quote/SBIN.BO/history?p=SBIN.BO
# /quote/SBIN.BO/profile?p=SBIN.BO
# /quote/SBIN.BO/financials?p=SBIN.BO
# /quote/SBIN.BO/analysis?p=SBIN.BO
# /quote/SBIN.BO/options?p=SBIN.BO
# /quote/SBIN.BO/holders?p=SBIN.BO
# /quote/SBIN.BO/sustainability?p=SBIN.BO
# /quote/SBIN.BO/news?p=SBIN.BO
# /quote/SBIN.BO/press-releases?p=SBIN.BO
# /news/sbis-credit-card-business-plans-164715145.html
# /news/indian-police-register-42-bank-163142648.html
# /news/indian-shares-rise-special-muhurat-154020430.html
# /news/state-bank-india-profit-triples-091717253.html
# /news/sbis-credit-card-business-aims-113627485.html
# /news/state-bank-india-cuts-benchmark-082101757.html
# /news/state-bank-india-seeks-bids-071022814.html
# /news/sbi-posts-profit-first-quarter-083245260.html
# /news/exclusive-sbi-tightens-lending-terms-175533859.html
# /news/exclusive-indias-sbi-tightens-lending-175450256.html
# /news/sbi-cuts-deposit-rates-keeps-104228583.html
# /news/jet-airways-lenders-approve-interim-142019586.html
# /news/lenders-bankrupt-jet-airways-attempt-025917265.html
# /news/wilful-defaults-india-cross-21-131914303.html
# /news/nclt-admits-insolvency-plea-against-134437326.html
# /news/nifty-sensex-edge-lower-over-050958387.html
# /news/jet-airways-slumps-reports-etihads-044735809.html
# /news/state-bank-india-says-two-095227463.html
# /news/state-bank-india-gets-sealed-142812373.html
# /news/state-bank-india-turns-profit-083353157.html
# /m/730e15e2-c699-3918-b5a0-169ab2239590/ss_don%26%2339%3Bt-blame-state-banks.html
# /m/cec40fb6-0b5b-3b15-b2ce-71581ece6c6a/ss_jet-airways%26%2339%3B-lenders-hope.html
# /news/timeline-jet-airways-joy-flying-151825293.html
# /m/77145535-3235-3f26-98b6-13fc79fd9922/ss_jet-airways-stock-suffers.html
# /m/8ed0cc96-18ee-3b60-9d01-ede17fc37b07/ss_india%26%2339%3Bs-jet-airways.html
# /
# /watchlists
# /budget
# /portfolios
# /personal-finance
# /topic/tech
# /topic/autos
# /topic/latestnews
# /topic/videos

# %%
len(soup.findAll('table'))
# Out:
# 2

# %%
mytable=soup.findAll('table')[0]
mytable.findAll('tr') #rows
# Out:
# [<tr class="Bxz(bb) Bdbw(1px) Bdbs(s) Bdc($seperatorColor) H(36px)" data-reactid="11"><td class="C($primaryColor) W(51%)" data-reactid="12"><span data-reactid="13">Previous close</span></td><td class="Ta(end) Fw(600) Lh(14px)" data-reactid="14" data-test="PREV_CLOSE-value"><span class="Trsdu(0.3s)" data-reactid="15">321.80</span></td></tr>,
#  <tr class="Bxz(bb) Bdbw(1px) Bdbs(s) Bdc($seperatorColor) H(36px)" data-reactid="16"><td class="C($primaryColor) W(51%)" data-reactid="17"><span data-reactid="18">Open</span></td><td class="Ta(end) Fw(600) Lh(14px)" data-reactid="19" data-test="OPEN-value"><span class="Trsdu(0.3s)" data-reactid="20">325.00</span></td></tr>,
#  <tr class="Bxz(bb) Bdbw(1px) Bdbs(s) Bdc($seperatorColor) H(36px)" data-reactid="21"><td class="C($primaryColor) W(51%)" data-reactid="22"><span data-reactid="23">Bid</span></td><td class="Ta(end) Fw(600) Lh(14px)" data-reactid="24" data-test="BID-value"><span class="Trsdu(0.3s)" data-reactid="25">332.70 x 0</span></td></tr>,
#  <tr class="Bxz(bb) Bdbw(1px) Bdbs(s) Bdc($seperatorColor) H(36px)" data-reactid="26"><td class="C($primaryColor) W(51%)" data-reactid="27"><span data-reactid="28">Ask</span></td><td class="Ta(end) Fw(600) Lh(14px)" data-reactid="29" data-test="ASK-value"><span class="Trsdu(0.3s)" data-reactid="30">333.00 x 0</span></td></tr>,
#  <tr class="Bxz(bb) Bdbw(1px) Bdbs(s) Bdc($seperatorColor) H(36px)" data-reactid="31"><td class="C($primaryColor) W(51%)" data-reactid="32"><span data-reactid="33">Day's range</span></td><td class="Ta(end) Fw(600) Lh(14px)" data-reactid="34" data-test="DAYS_RANGE-value">324.85 - 333.55</td></tr>,
#  <tr class="Bxz(bb) Bdbw(1px) Bdbs(s) Bdc($seperatorColor) H(36px)" data-reactid="35"><td class="C($primaryColor) W(51%)" data-reactid="36"><span data-reactid="37">52-week range</span></td><td class="Ta(end) Fw(600) Lh(14px)" data-reactid="38" data-test="FIFTY_TWO_WK_RANGE-value">244.35 - 373.70</td></tr>,
#  <tr class="Bxz(bb) Bdbw(1px) Bdbs(s) Bdc($seperatorColor) H(36px)" data-reactid="39"><td class="C($primaryColor) W(51%)" data-reactid="40"><span data-reactid="41">Volume</span></td><td class="Ta(end) Fw(600) Lh(14px)" data-reactid="42" data-test="TD_VOLUME-value"><span class="Trsdu(0.3s)" data-reactid="43">1901460</span></td></tr>,
#  <tr class="Bxz(bb) Bdbw(1px) Bdbs(s) Bdc($seperatorColor) H(36px) Bdbw(0)!" data-reactid="44"><td class="C($primaryColor) W(51%)" data-reactid="45"><span data-reactid="46">Avg. volume</span></td><td class="Ta(end) Fw(600) Lh(14px)" data-reactid="47" data-test="AVERAGE_VOLUME_3MONTH-value"><span class="Trsdu(0.3s)" data-reactid="48">1,874,153</span></td></tr>]

# %%
for rows in mytable.findAll('tr'):
    data=rows.findAll('td') #table-data
    print_data=[]
    for d in data:
        print_data.append(d.text)
    print(print_data)
# Out:
# ['Previous close', '321.80']
# ['Open', '325.00']
# ['Bid', '332.70 x 0']
# ['Ask', '333.00 x 0']
# ["Day's range", '324.85 - 333.55']
# ['52-week range', '244.35 - 373.70']
# ['Volume', '1901460']
# ['Avg. volume', '1,874,153']

# %% [markdown]
# ## Google Scraping

# %%
# !pip install google_images_download

# %%
from google_images_download import google_images_download

# %%
response = google_images_download.googleimagesdownload()

# %%
entity = "sachin"
num_images = 10
output_dir = "downloads"
log_file= "error.log"

# %%
response.download({'keywords':entity, 
                   'limit':num_images, 
                   "output_directory":output_dir, 
                   "extract_metadata": log_file});
# Out:
# Item no.: 1 --> Item name = sachin
# Evaluating...
# Starting Download...
# Completed Image ====> 1.Sachin_Tendulkar_at_MRF_Promotion_Event.jpg
# Completed Image ====> 2.RTS2K95P-770x433.jpeg
# Invalid or missing image format. Skipping...
# Completed Image ====> 3.25.jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 4.sachin-tendulkar.jpg
# Completed Image ====> 5.Sachin-kAuF--621x414@LiveMint_1556439621173.jpg
# Completed Image ====> 6.sachin-turns-44-ten-facts-that-you-probably-didnt-know-about-tendulkar.jpg
# Completed Image ====> 7.Sachin-Tendulkar-CWC19-Reuters-380.jpg
# Invalid or missing image format. Skipping...
# Completed Image ====> 8.816304-814706-sachin-tendulkar-twitter.jpg
# Completed Image ====> 9.final-of-ipl-t20-2019-csk-vs_4e5630ec-7722-11e9-b041-b8edd22396b2.jpg
# Completed Image ====> 10.sachin.jpg
#
# Errors: 3

# %%
from requests_html import HTMLSession
import os

class EntityScraper:

	def __init__(self, query, num_entities):

		self.payload = {'q': query}
		self.session = HTMLSession()
		self.num_entities = num_entities

	def scrape(self):

		r = self.session.get("https://www.google.co.in/search", params=self.payload)
		if r.status_code == 200:
			tags = r.html.find(".klitem")
			if not tags:
				raise Exception("Bad query, please try again")

			entity_list = []
			for tag in tags:
				entity_list.append(tag.attrs['aria-label'])

			if len(entity_list) > self.num_entities:
			    entity_list = entity_list[:self.num_entities]

			print("Entity list obtained is {}".format(entity_list))
    
		else:
			raise Exception("status code " + str(r.status_code))

		return entity_list

# %%
scraper = EntityScraper('top actors in india', 5)

# %%
scraper.scrape()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-3-c061b0f3c0e7> in <module>
# ----> 1 scraper.scrape()
#
# <ipython-input-1-4a723a11b8e7> in scrape(self)
#      16                         tags = r.html.find(".klitem")
#      17                         if not tags:
# ---> 18                                 raise Exception("Bad query, please try again")
#      19
#      20                         entity_list = []
#
# Exception: Bad query, please try again
